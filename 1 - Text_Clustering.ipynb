# %% [markdown]
# # Global Configurations

# %%
# -*- coding: utf-8 -*-

# %%
# enable functionalities
# %config IPCompleter.greedy=True  # auto-complete

# %%
# import the dependencies
import os

# %%
# define the global variables
BASE_DIR = os.path.abspath('')
DATA_DIR = os.path.join(BASE_DIR, 'data')
REQUESTS_PATH = os.path.join(DATA_DIR5, 'General Request Data.csv')
AMAZON_REVIEW_PATH = os.path.join(DATA_DIR, 'AmazonReview.csv')
SPACY_PROCESSED_PATH = os.path.join(DATA_DIR, 'spacy_processed.pickle')
REQUEST_DATA_PATH = os.path.join(DATA_DIR, 'clean_requests.pickle')

# %% [markdown]
# # Text Cleaning

# %%
# import the dependencies
import pandas as pd
import re
import copy
from urlextract import URLExtract
import numpy as np
import string
import pickle

# %%
# read the data from the CSV file
data = pd.read_csv(REQUESTS_PATH)

# view the stats of the dataframe
print("There are", data.shape[0], "rows and", data.shape[1], "coloumns in the data set.")
print("The columns are:", list(data.columns))
data.head()
# Out:
# There are 92541 rows and 12 coloumns in the data set.
# The columns are: ['closed_at', 'opened_at', 'parent', 'number', 'assignment_group', 'assigned_to', 'priority', 'request_item.cat_item', 'state', 'short_description', 'u_description', 'description']
#        closed_at      opened_at       parent       number  \
# 0  1/11/19 10:43    1/7/19 3:43  RITM0601256  TASK0732614
# 1  6/26/17 23:50   6/22/17 0:45  RITM0226606  TASK0252360
# 2   5/16/16 4:21    5/2/16 0:52  RITM0050286  TASK0051491
# 3   5/3/19 14:22   5/3/19 12:01  RITM0715674  TASK0887223
# 4    7/8/19 5:50  6/29/19 19:08  RITM0772088  TASK0949305
#
#               assignment_group       assigned_to priority  \
# 0  PSG.CTD.IS.FCS Service Desk   Ivan Dos Santos  4 - Low
# 1       ETO.EES.SD.ATS Support     Zhang Chunlin  4 - Low
# 2        LSG.BID.DS.LT Vilnius  Andrius Stirblys  4 - Low
# 3                 Service Desk               NaN  4 - Low
# 4            LATAM.APPLICATION      Marcos Betto  4 - Low
#
#   request_item.cat_item              state  \
# 0       General Request    Closed Complete
# 1       General Request    Closed Complete
# 2       General Request    Closed Complete
# 3       General Request  Closed Incomplete
# 4       General Request    Closed Complete
#
#                                    short_description  u_description  \
# 0  General Request: Acceso a Internet - Estudio C...            NaN
# 1  General Request: request to forward email to s...            NaN
# 2                                    General Request            NaN
# 3  General Request: Materila should be removed fr...            NaN
# 4  General Request: INCLUIR LOTES EM PEDIDOS FATU...            NaN
#
#                                          description
# 0  Se necesita acceso a internet para el siguient...
# 1  hi, \r\nwould like to request to foward CheeCh...
# 2  Prašau priskirti šią užduotį Lithuania.Vilnius...
# 3  The material PN 76157 - Receipt ID DR320474 - ...
# 4  Boa noite Andrei, poderia por favor alocar man...

# %%
# # use spacy nlp libary to process the raw review texts
# nlp = spacy.load('en')
# precessed_request_texts = [nlp(text) for text in request_texts]

# # save the results
# with open(SPACY_PROCESSED_PATH, 'wb') as f:
#     pickle.dump(precessed_request_texts, f)
# f.close()

# %%
# get all the request texts from the data set
request_short_descriptions = []
request_long_descriptions = []
request_full_descriptions = []
invalid_count = 0
for index, row in data.iterrows():
    row_text = ''
    # if the description section is NaN, then record an empty string
    if type(row['short_description']) == str:
        row_text += row['short_description'] + ' '
        request_short_descriptions.append(row['short_description'])
    else:
        request_short_descriptions.append('')
    if type(row['description']) == str:
        row_text += row['description']
        request_long_descriptions.append(row['description'])
    else:
        request_short_descriptions.append('')    
    request_full_descriptions.append(row_text)
    
# preview the request_texts
display(pd.DataFrame({'full description':request_full_descriptions[:15]}))

# count the number of characters
def count_chars(string_array, array_name):
    character_count = 0
    for text in string_array:
        character_count += len(text)
    print("The character number of", array_name, "is", character_count)
    
count_chars(request_short_descriptions, "short descriptions")
count_chars(request_long_descriptions, "long descriptions")
count_chars(request_full_descriptions, "full descriptions")
# Out:
#                                      full description
# 0   General Request: Acceso a Internet - Estudio C...
# 1   General Request: request to forward email to s...
# 2   General Request Prašau priskirti šią užduotį L...
# 3   General Request: Materila should be removed fr...
# 4   General Request: INCLUIR LOTES EM PEDIDOS FATU...
# 5   Request to remove SNOW Subcategory Request Gen...
# 6   WIN 10 REIMAGE - Junwei Su Need to upgrade my ...
# 7   General Request: can you please extend GL code...
# 8   General Request: Unipoint uploads Good afterno...
# 9   General Request: need computer connected to la...
# 10  General Request: 人事情報変更リスト（復職 榎本　好宏さん）to Sato ...
# 11  General Request: Report extraction from TRAX P...
# 12  General Request: Neteisingas fasavimo ruošinio...
# 13  General Request: Leads Uploaded to SFDC  (BMK ...
# 14  General Request: New Vendor To Be Added To GPM...
# The character number of short descriptions is 5501687
# The character number of long descriptions is 20766382
# The character number of full descriptions is 26360593

# %%
# erase non English requests
def removeNonEnglish(string_array):
    english_strings = []
    for string in string_array:
        try:
            string.encode(encoding='utf-8').decode('ascii')
        except UnicodeDecodeError:
            english_strings.append('')
        else:
            english_strings.append(string)
    display(pd.DataFrame({'before':string_array, 'after':english_strings})[:15])
    return english_strings

#short_descriptions_Engish = removeNonEnglish(request_short_descriptions)
#long_descriptions_Engish = removeNonEnglish(request_long_descriptions)
full_descriptions_Engish = removeNonEnglish(request_full_descriptions)
# Out:
#                                                before  \
# 0   General Request: Acceso a Internet - Estudio C...
# 1   General Request: request to forward email to s...
# 2   General Request Prašau priskirti šią užduotį L...
# 3   General Request: Materila should be removed fr...
# 4   General Request: INCLUIR LOTES EM PEDIDOS FATU...
# 5   Request to remove SNOW Subcategory Request Gen...
# 6   WIN 10 REIMAGE - Junwei Su Need to upgrade my ...
# 7   General Request: can you please extend GL code...
# 8   General Request: Unipoint uploads Good afterno...
# 9   General Request: need computer connected to la...
# 10  General Request: 人事情報変更リスト（復職 榎本　好宏さん）to Sato ...
# 11  General Request: Report extraction from TRAX P...
# 12  General Request: Neteisingas fasavimo ruošinio...
# 13  General Request: Leads Uploaded to SFDC  (BMK ...
# 14  General Request: New Vendor To Be Added To GPM...
#
#                                                 after
# 0   General Request: Acceso a Internet - Estudio C...
# 1   General Request: request to forward email to s...
# 2
# 3   General Request: Materila should be removed fr...
# 4   General Request: INCLUIR LOTES EM PEDIDOS FATU...
# 5   Request to remove SNOW Subcategory Request Gen...
# 6   WIN 10 REIMAGE - Junwei Su Need to upgrade my ...
# 7   General Request: can you please extend GL code...
# 8   General Request: Unipoint uploads Good afterno...
# 9   General Request: need computer connected to la...
# 10
# 11  General Request: Report extraction from TRAX P...
# 12
# 13  General Request: Leads Uploaded to SFDC  (BMK ...
# 14  General Request: New Vendor To Be Added To GPM...

# %%
# drop the empty rows
def drop_empty(string_array, array_name):
    count = 0
    no_empty_string = []
    for text in string_array:
        if len(text):
            no_empty_string.append(text)
        else:
            count += 1
    print("lost", count, '(', count/len(string_array)*100, "%)", "non English rows in", array_name)
    display(pd.DataFrame({'empty strings are removed':no_empty_string})[:15])
    return no_empty_string

#short_descriptions_Engish = drop_empty(short_descriptions_Engish, "short descriptions")
#long_descriptions_Engish = drop_empty(long_descriptions_Engish, "long descriptions")
full_descriptions_Engish = drop_empty(full_descriptions_Engish, "full descriptions")

# # compare with Amazon review data
# Amazon_review_data = pd.read_csv(AMAZON_REVIEW_PATH, usecols=[16])
# Amazon_review_data.head()
# Out:
# lost 14899 ( 16.09989085918674 %) non English rows in full descriptions
#                             empty strings are removed
# 0   General Request: Acceso a Internet - Estudio C...
# 1   General Request: request to forward email to s...
# 2   General Request: Materila should be removed fr...
# 3   General Request: INCLUIR LOTES EM PEDIDOS FATU...
# 4   Request to remove SNOW Subcategory Request Gen...
# 5   WIN 10 REIMAGE - Junwei Su Need to upgrade my ...
# 6   General Request: can you please extend GL code...
# 7   General Request: Unipoint uploads Good afterno...
# 8   General Request: need computer connected to la...
# 9   General Request: Report extraction from TRAX P...
# 10  General Request: Leads Uploaded to SFDC  (BMK ...
# 11  General Request: New Vendor To Be Added To GPM...
# 12  General Request: I need to have the smartsheet...
# 13  General Request: Please provide a computer set...
# 14  General Request: Project Closure 1342 I have b...

# %%
regex = re.compile(r"()")
re.sub(regex, ' # ', "''")
# for text in full_descriptions_ready:
#     if 'ustew-ftn8n02' in text:
#         print(text)
# Out:
# " # ' # ' # "

# %%
# remove unwanted characters
# ejm: email
# ljk: URL/link
# ajn: alphanumerics
# ljg: long word
# njm: number
# djt: date
# pjt: path
def clean(string_array, array_name):
    regex_email = re.compile(r'[\w\.-]+@[\w\.-]+')
    regex_general = re.compile(r"^general request:?\s*", re.IGNORECASE)
    regex_hashcode = re.compile(r'( [a-zA-z-]+[0-9]+[a-zA-z0-9-]* | [0-9]+[a-zA-z-]+[a-zA-z0-9-]* )')
    regex_long = re.compile(r'[a-zA-z-]{20,}')
    regex_num = re.compile(r'[0-9]+')
    regex_date = re.compile(r'( [0-9]{4}[./-]+[0-9]{2}[./-]+[0-9]{2} | [0-9]{2}[./-]+[0-9]{2}[./-]+[0-9]{4} )')
    regex_path = re.compile(r" [a-zA-Z_.:']*(\\|/){1,2}[a-zA-Z_.]+(\\|/){1,2}[a-zA-Z_.]+(\\|/){1,2}[a-zA-Z_.\\/']* ")
    
    regex_punc = re.compile(r'[#~`^!"*,;?()<>{}\[\]]')
    regex_space = re.compile(r'\s\s+|^\s+|\s+$')
    regex_dash = re.compile(r'--+')
    regex_slash = re.compile(r'[-+=_%.:\\/@\$\|]')
    regex_quote = re.compile(r"('')")
    regex_ejm = re.compile(r'( ejm )(ejm )+')
    regex_ljk = re.compile(r'( ljk )(ljk )+')
    regex_ajn = re.compile(r'( ajn )(ajn )+')
    regex_ljg = re.compile(r'( ljg )(ljg )+')
    regex_njm = re.compile(r'( njm )(njm )+')
    regex_djt = re.compile(r'( djt )(djt )+')
    regex_pjt = re.compile(r'( pjt )(pjt )+')
    
    url_extractor = URLExtract()
    string_array_cleaned = copy.deepcopy(string_array)
    for index, string in enumerate(string_array_cleaned):
        # get rid of tabs(\t), returns(\r), and newlines(\n)
        string_array_cleaned[index] = string.translate({ord(i): ' ' for i in '\n\t\r'})
        
        # delete "General Request: "
        string_array_cleaned[index] = re.sub(regex_general, '', string_array_cleaned[index])
        
        # replace all the email address with ejm
        string_array_cleaned[index] = re.sub(regex_email, ' ejm ', string_array_cleaned[index])
        
        # substitute urls with 'ljk'
        urls = url_extractor.find_urls(string_array_cleaned[index])
        for url in urls:
            string_array_cleaned[index] = string_array_cleaned[index].replace(url, ' ljk ')
            
        # drop the punctuations
        string_array_cleaned[index] = re.sub(regex_punc, ' ', string_array_cleaned[index])
        
        # convert to lower case
        string_array_cleaned[index] = string_array_cleaned[index].lower()
        
        # substitute date code with 'djt'
        string_array_cleaned[index] = re.sub(regex_date, ' djt ', string_array_cleaned[index])
        
        # substitute path with 'pjt'
        string_array_cleaned[index] = re.sub(regex_path, ' pjt ', string_array_cleaned[index])
        
        # substitute alphanumerical words(e.g. ab0xec) with ajn
        string_array_cleaned[index] = re.sub(regex_hashcode, ' ajn ', string_array_cleaned[index])
        
        # substitute numbers with 'njm'
        string_array_cleaned[index] = re.sub(regex_num, ' njm ', string_array_cleaned[index])
        
        # substitute long words with 'ljg'
        string_array_cleaned[index] = re.sub(regex_long, ' ljg ', string_array_cleaned[index])
        
        # drop slash
        string_array_cleaned[index] = re.sub(regex_slash, ' ', string_array_cleaned[index])
        
        # drop all the trailing whitespaces( ) and dashes(-)
        string_array_cleaned[index] = re.sub(regex_space, ' ', string_array_cleaned[index])
        string_array_cleaned[index] = re.sub(regex_dash, '-', string_array_cleaned[index])
        
        # drop ''
        string_array_cleaned[index] = re.sub(regex_quote, ' ', string_array_cleaned[index])
        
        # reduce the number of tokens
        string_array_cleaned[index] = re.sub(regex_ejm, ' ejm ', string_array_cleaned[index])
        string_array_cleaned[index] = re.sub(regex_ljk, ' ljk ', string_array_cleaned[index])
        string_array_cleaned[index] = re.sub(regex_ajn, ' ajn ', string_array_cleaned[index])
        string_array_cleaned[index] = re.sub(regex_ljg, ' ljg ', string_array_cleaned[index])
        string_array_cleaned[index] = re.sub(regex_njm, ' njm ', string_array_cleaned[index])
        string_array_cleaned[index] = re.sub(regex_djt, ' djt ', string_array_cleaned[index])
        string_array_cleaned[index] = re.sub(regex_pjt, ' pjt ', string_array_cleaned[index])
    #     # replace \u3000 with whitespace
    #     request_short_descriptions_cleaned[index] = request_short_descriptions_cleaned[index].replace('\u3000', ' ')
    # display the processed data
    print('The character number of cleaned', array_name, 'is', sum([len(text) for text in string_array_cleaned]))
    display(pd.DataFrame({'before':string_array, 'after':string_array_cleaned})[:15])
    return string_array_cleaned
        
# call the clean function to clean the texts for times
#request_short_descriptions_cleaned = copy.deepcopy(request_short_descriptions)
#request_long_descriptions_cleaned = copy.deepcopy(request_long_descriptions)
request_full_descriptions_cleaned = copy.deepcopy(full_descriptions_Engish)
for i in range(5):
    #request_short_descriptions_cleaned = clean(request_short_descriptions_cleaned, "short descriptions")
    #request_long_descriptions_cleaned = clean(request_long_descriptions_cleaned, "long descriptions")
    request_full_descriptions_cleaned = clean(request_full_descriptions_cleaned, "full descriptions")
# Out:
# The character number of cleaned full descriptions is 16835957
#                                                before  \
# 0   General Request: Acceso a Internet - Estudio C...
# 1   General Request: request to forward email to s...
# 2   General Request: Materila should be removed fr...
# 3   General Request: INCLUIR LOTES EM PEDIDOS FATU...
# 4   Request to remove SNOW Subcategory Request Gen...
# 5   WIN 10 REIMAGE - Junwei Su Need to upgrade my ...
# 6   General Request: can you please extend GL code...
# 7   General Request: Unipoint uploads Good afterno...
# 8   General Request: need computer connected to la...
# 9   General Request: Report extraction from TRAX P...
# 10  General Request: Leads Uploaded to SFDC  (BMK ...
# 11  General Request: New Vendor To Be Added To GPM...
# 12  General Request: I need to have the smartsheet...
# 13  General Request: Please provide a computer set...
# 14  General Request: Project Closure 1342 I have b...
#
#                                                 after
# 0   acceso a internet estudio contable argentina s...
# 1   request to forward email to shared mailbox hi ...
# 2   materila should be removed from gpm the materi...
# 3   incluir lotes em pedidos faturados boa noite a...
# 4   request to remove snow subcategory request gen...
# 5   win njm reimage junwei su need to upgrade my l...
# 6   can you please extend gl code njm to plant njm...
# 7   unipoint uploads good afternoon when i attach ...
# 8   need computer connected to landline can you pl...
# 9   report extraction from trax pr screen please a...
# 10  leads uploaded to sfdc bmk njm shm need to upl...
# 11  new vendor to be added to gpm vendor list new ...
# 12  i need to have the smartsheet application add ...
# 13  please provide a computer set up to access cnc...
# 14  project closure njm i have been notified to cl...
# The character number of cleaned full descriptions is 16835137
#                                                before  \
# 0   acceso a internet estudio contable argentina s...
# 1   request to forward email to shared mailbox hi ...
# 2   materila should be removed from gpm the materi...
# 3   incluir lotes em pedidos faturados boa noite a...
# 4   request to remove snow subcategory request gen...
# 5   win njm reimage junwei su need to upgrade my l...
# 6   can you please extend gl code njm to plant njm...
# 7   unipoint uploads good afternoon when i attach ...
# 8   need computer connected to landline can you pl...
# 9   report extraction from trax pr screen please a...
# 10  leads uploaded to sfdc bmk njm shm need to upl...
# 11  new vendor to be added to gpm vendor list new ...
# 12  i need to have the smartsheet application add ...
# 13  please provide a computer set up to access cnc...
# 14  project closure njm i have been notified to cl...
#
#                                                 after
# 0   acceso a internet estudio contable argentina s...
# 1   request to forward email to shared mailbox hi ...
# 2   materila should be removed from gpm the materi...
# 3   incluir lotes em pedidos faturados boa noite a...
# 4   request to remove snow subcategory request gen...
# 5   win njm reimage junwei su need to upgrade my l...
# 6   can you please extend gl code njm to plant njm...
# 7   unipoint uploads good afternoon when i attach ...
# 8   need computer connected to landline can you pl...
# 9   report extraction from trax pr screen please a...
# 10  leads uploaded to sfdc bmk njm shm need to upl...
# 11  new vendor to be added to gpm vendor list new ...
# 12  i need to have the smartsheet application add ...
# 13  please provide a computer set up to access cnc...
# 14  project closure njm i have been notified to cl...
# The character number of cleaned full descriptions is 16835105
#                                                before  \
# 0   acceso a internet estudio contable argentina s...
# 1   request to forward email to shared mailbox hi ...
# 2   materila should be removed from gpm the materi...
# 3   incluir lotes em pedidos faturados boa noite a...
# 4   request to remove snow subcategory request gen...
# 5   win njm reimage junwei su need to upgrade my l...
# 6   can you please extend gl code njm to plant njm...
# 7   unipoint uploads good afternoon when i attach ...
# 8   need computer connected to landline can you pl...
# 9   report extraction from trax pr screen please a...
# 10  leads uploaded to sfdc bmk njm shm need to upl...
# 11  new vendor to be added to gpm vendor list new ...
# 12  i need to have the smartsheet application add ...
# 13  please provide a computer set up to access cnc...
# 14  project closure njm i have been notified to cl...
#
#                                                 after
# 0   acceso a internet estudio contable argentina s...
# 1   request to forward email to shared mailbox hi ...
# 2   materila should be removed from gpm the materi...
# 3   incluir lotes em pedidos faturados boa noite a...
# 4   request to remove snow subcategory request gen...
# 5   win njm reimage junwei su need to upgrade my l...
# 6   can you please extend gl code njm to plant njm...
# 7   unipoint uploads good afternoon when i attach ...
# 8   need computer connected to landline can you pl...
# 9   report extraction from trax pr screen please a...
# 10  leads uploaded to sfdc bmk njm shm need to upl...
# 11  new vendor to be added to gpm vendor list new ...
# 12  i need to have the smartsheet application add ...
# 13  please provide a computer set up to access cnc...
# 14  project closure njm i have been notified to cl...
# The character number of cleaned full descriptions is 16835089
#                                                before  \
# 0   acceso a internet estudio contable argentina s...
# 1   request to forward email to shared mailbox hi ...
# 2   materila should be removed from gpm the materi...
# 3   incluir lotes em pedidos faturados boa noite a...
# 4   request to remove snow subcategory request gen...
# 5   win njm reimage junwei su need to upgrade my l...
# 6   can you please extend gl code njm to plant njm...
# 7   unipoint uploads good afternoon when i attach ...
# 8   need computer connected to landline can you pl...
# 9   report extraction from trax pr screen please a...
# 10  leads uploaded to sfdc bmk njm shm need to upl...
# 11  new vendor to be added to gpm vendor list new ...
# 12  i need to have the smartsheet application add ...
# 13  please provide a computer set up to access cnc...
# 14  project closure njm i have been notified to cl...
#
#                                                 after
# 0   acceso a internet estudio contable argentina s...
# 1   request to forward email to shared mailbox hi ...
# 2   materila should be removed from gpm the materi...
# 3   incluir lotes em pedidos faturados boa noite a...
# 4   request to remove snow subcategory request gen...
# 5   win njm reimage junwei su need to upgrade my l...
# 6   can you please extend gl code njm to plant njm...
# 7   unipoint uploads good afternoon when i attach ...
# 8   need computer connected to landline can you pl...
# 9   report extraction from trax pr screen please a...
# 10  leads uploaded to sfdc bmk njm shm need to upl...
# 11  new vendor to be added to gpm vendor list new ...
# 12  i need to have the smartsheet application add ...
# 13  please provide a computer set up to access cnc...
# 14  project closure njm i have been notified to cl...
# The character number of cleaned full descriptions is 16835089
#                                                before  \
# 0   acceso a internet estudio contable argentina s...
# 1   request to forward email to shared mailbox hi ...
# 2   materila should be removed from gpm the materi...
# 3   incluir lotes em pedidos faturados boa noite a...
# 4   request to remove snow subcategory request gen...
# 5   win njm reimage junwei su need to upgrade my l...
# 6   can you please extend gl code njm to plant njm...
# 7   unipoint uploads good afternoon when i attach ...
# 8   need computer connected to landline can you pl...
# 9   report extraction from trax pr screen please a...
# 10  leads uploaded to sfdc bmk njm shm need to upl...
# 11  new vendor to be added to gpm vendor list new ...
# 12  i need to have the smartsheet application add ...
# 13  please provide a computer set up to access cnc...
# 14  project closure njm i have been notified to cl...
#
#                                                 after
# 0   acceso a internet estudio contable argentina s...
# 1   request to forward email to shared mailbox hi ...
# 2   materila should be removed from gpm the materi...
# 3   incluir lotes em pedidos faturados boa noite a...
# 4   request to remove snow subcategory request gen...
# 5   win njm reimage junwei su need to upgrade my l...
# 6   can you please extend gl code njm to plant njm...
# 7   unipoint uploads good afternoon when i attach ...
# 8   need computer connected to landline can you pl...
# 9   report extraction from trax pr screen please a...
# 10  leads uploaded to sfdc bmk njm shm need to upl...
# 11  new vendor to be added to gpm vendor list new ...
# 12  i need to have the smartsheet application add ...
# 13  please provide a computer set up to access cnc...
# 14  project closure njm i have been notified to cl...

# %%
# # translate the non-English sentences
# translate_urls = ["translate.google.com", "translate.google.co.kr",
#                       "translate.google.at", "translate.google.de",
#                       "translate.google.ru", "translate.google.ch",
#                       "translate.google.fr", "translate.google.es"]
# sample_japanese_request = request_texts[10]
# translated_requests = []

# for index, request_raw in enumerate(request_texts):
#     translator = Translator(service_urls=translate_urls)
#     try:
#         request_tanslated = translator.translate(request_raw, dest='en')
#         translated_requests.append(request_tanslated.text)
#     except:
#         translated_requests.append('')
#         print(index)

# %%
# compare with Amazon review data
Amazon_review_data = pd.read_csv(AMAZON_REVIEW_PATH, usecols=[16])
Amazon_review_data.head(20)
# Out:
#                                          reviews.text
# 0   This product so far has not disappointed. My c...
# 1   great for beginner or experienced person. Boug...
# 2   Inexpensive tablet for him to use and learn on...
# 3   I've had my Fire HD 8 two weeks now and I love...
# 4   I bought this for my grand daughter when she c...
# 5   This amazon fire 8 inch tablet is the perfect ...
# 6   Great for e-reading on the go, nice and light ...
# 7   I gave this as a Christmas gift to my inlaws, ...
# 8   Great as a device to read books. I like that i...
# 9   I love ordering books and reading them with th...
# 10  Not easy for elderly users cease of ads that p...
# 11  Excellent product. Easy to use, large screen m...
# 12  Wanted my father to have his first tablet and ...
# 13  Simply does everything I need. Thank youAnd si...
# 14  Got it as a present and love the size of the s...
# 15  The kindle is easiest to use, graphics and scr...
# 16  nice reader. almost perfect for what i want/ne...
# 17  I really like this tablet. I would have given ...
# 18  Great video quality lots of fun apps fun for t...
# 19  Love love love my kindle fire 8.....this is wh...

# %%
# view stats of the requests
def view_stats (str_array, array_name):
    string_array = copy.deepcopy(str_array)
    
    avg_char = sum([len(text) for text in string_array]) / len(string_array)
    print("the average length of", array_name, "is:", avg_char, "characters")
    avg_word = sum([len(text.split(' ')) for text in string_array]) / len(string_array)
    print("the average word count of", array_name, "is:", avg_word)
    MAX_LENGTH = max([len(text.split(' ')) for text in string_array])
    print("the longest request has", MAX_LENGTH, "words")
    
    count = 0
    longest_texts = []
    longest_text = ''
    for index,text in enumerate(string_array):
        if len(text.split(' ')) > (avg_word):
            count += 1
        if len(text.split(' ')) == MAX_LENGTH:
            longest_text = text
            continue
        if len(text.split(' ')) > (avg_word*10):
            longest_texts.append(text)
            string_array[index] = text[:int(avg_word*10)]
    print(len(longest_texts), '(', 100*len(longest_texts)/len(string_array), "%) strings are longer than (10 * average). They are all cut to", int(avg_word*10))
    print(count, '(', int(100*count/len(string_array)), "%) strings are longer than average")
    print("the longest one is:", longest_text, )
    print('other longest strings are:')
    for text in longest_texts:
        print('length', len(text.split(' ')))
        print(text)
    
    # save the results
    with open(REQUEST_DATA_PATH, 'wb') as target:
        pickle.dump(string_array, target)
    target.close()
    print("the strings are pickled")
    
view_stats(request_full_descriptions_cleaned, 'full descriptions')

# from operator import itemgetter
# index, element = max(enumerate([len(text.split(' ')) for text in full_descriptions_ready]), key=itemgetter(1))
# full_descriptions_ready[index]
# Out:
# the average length of full descriptions is: 216.8296669328456 characters
# the average word count of full descriptions is: 39.636317972231524
# the longest request has 3454 words
# 69 ( 0.08886942634141315 %) strings are longer than (10 * average). They are all cut to 396
# 27865 ( 35 %) strings are longer than average
# the longest one is: pds business report distribution list updates received from ejm hello please remove the following people from the pds business report distribution list thanks andi from microsoft outlook mailto ejm sent njm december njm to cavilla andrew subject undeliverable pds business report njm december njm delivery has failed to these recipients or groups ejm mailto ejm a problem occurred during the delivery of this message please try to resend the message later ejm mailto ejm a problem occurred during the delivery of this message please try to resend the message later the following organisation rejected your message ljk diagnostic information for administrators generating server ljk ejm ljk njm hop count exceeded possible mail loop ajn ljk ajn ejm ljk njm hop count exceeded possible mail loop ajn ljk ajn ejm original message headers received from ljk njm by ljk njm with microsoft smtp server tls id njm mon njm dec njm ajn received from ljk njm b njm de njm by ljk njm b njm with microsoft smtp server version tls njm cipher ljg njm gcm sha njm id njm mon njm dec njm received from ljk njm a njm f njm e njm by ljk njm b njm de njm with microsoft smtp server version tls njm cipher ljg njm cbc sha njm id njm via frontend transport mon njm dec njm ljg spf permerror sender ip is njm smtp mailfrom ljk patheonpharma mail onmicrosoft com dkim none message not signed header d none patheonpharma mail onmicrosoft com dmarc none action none header from ljk received spf permerror ljk domain of ljk used an invalid spf mechanism received from ljk njm by by njm nam njm ft njm mail ljk njm with microsoft smtp server version tls njm cipher ljg njm cbc sha nj
#  items minimum order charge not applied when line is splitted report request ajn converted to request hi ticket ajn has been raised by aude glandus around charges not being applied due to split order the ticket has been closed bymarcel schwark because the system was working as designed which is fine the purpose of this new request is to understand the potential impact of this design request could you send me a file reflecting for europe the orders where we did not charge a moc due to the fact that we had a split order assuming customer is not flagged nomoc you will find below the information provided by marcel in the initial ticket inc njm thank you for your support ljg hi aude i discussed the ticket with david poinsot and did some additional tests on the issue the reason why the nomoc charges was not applied is because the order line was split in njm lines at the time the sales order was created if a sales order is created with order fulfillment rule njm and only partial quantity is available the order quantity will be split in njm lines one line is created for the available quantity with today dispatch date and a second line is created for the remaining quantity with a future delivery date in the charge retrieval program it is specifically checked if a line has been split for that purpose and if this is the case the check against order amount weight and volume is not performed which means the charges based on amounts are not applied in case a order line has be split into njm lines because of partial availability the way the logic is implemented it does not make a difference if the charge is a header or line charge i did a few tests in ch company using the same item and customer as in your order if order quantity is njm and only njm pcs is available the order qty was split into njm lines no charges was applied if order quantity is njm and quantity is fully available the order line was not split and charge was applied so it is clearly the logic checking for split order lines that is causing the header charge is not applied the logic to exclude split order lines logic from the amount limit check is part of the original development and was specifically foreseen that way there is even a comment in code describing this for lines created due to split do not check quantity limits total original quantity for both lines may be greater than lower limit due to this amount limit is not checked either so this is not a bug and if the logic needs to be changed a change request is required please discuss with david if he can create a change request he is in copy of the ticket i will close the ticket as the system is apparently working as designed
# length 405
# monitoring for regensburg please assign to gis monitoring setup standard monitoring for the following servers name domain os type phys virtual ip ajn emea win srv njm ajn std p ljk ajn ads winsrv njm ajn std vm ljk ajn ads winsrv njm ajn std vm ljk ajn ads winsrv njm ajn std vm ljk ajn ads winsrv njm ajn std vm ljk ajn ads winsrv njm ajn std vm ljk ajn ads winsrv njm ajn std vm ljk ajn ads winsrv njm ajn std vm ljk njm ajn ads winsrv njm ajn std vm ljk ajn ads winsrv njm ajn std vm ljk ajn ads winsrv njm std vm ljk ajn emea win srv njm ajn std vm ljk ajn emea win srv njm ajn std vm ljk ajn emea win srv njm ajn std vm ljk ajn emea win srv njm ajn std vm ljk ajn emea win srv njm ajn std vm ljk ajn emea win srv njm ajn std vm ljk ajn emea win srv njm ajn std vm ljk ajn emea win srv njm ajn std vm ljk ajn emea win srv njm ajn std vm ljk ajn emea win srv njm ajn std vm ljk ajn emea win srv njm ajn std vm ljk ajn emea win srv njm ajn std vm ljk ajn emea winsrv njm ajn std vm ljk ajn emea winsrv njm ajn std vm ljk ajn emea winsrv njm ajn std vm ljk ajn emea winsrv njm ajn std vm ljk ajn emea winsrv njm ajn std vm ljk ajn emea winsrv njm ajn std vm ljk ajn emea winsrv njm ajn std vm ljk ajn emea winsrv njm ajn std vm ljk ajn emea winsrv njm ajn std vm ljk ajn emea winsrv njm ajn std vm ljk njm ajn emea winsrv njm ajn std vm ljk njm ajn emea winsrv njm ajn std vm ljk njm ajn emea winsrv njm ajn std vm ljk ajn emea win srv njm ajn std vm ljk ajn emea win srv njm ajn std vm ljk ajn emea linux p ljk ajn emea linux p ljk ajn emea linux p ljk ajn emea linux p ljk ajn emea linux p ljk ajn emea linux p ljk ajn emea linux p ljk njm ajn emea linux p ljk njm ajn ads win srv njm ajn std p ljk ajn ads win srv njm ajn std p ljk
# length 1827
# bsd fbs nautilus westat cnos for return cdc samples ajn received from ejm from poku akwasi a sent tuesday june njm pm to mccann gerard m ejm cc urco mary e ejm outarsingh clarissa i ejm dhokia pratish k ejm subject fw westat cnos for return cdc samples ajn hi remember the return westat plates that you help me on last year well we have a couple more of them that arrived two weeks ago i just want to know if i have to do the same thing as last time and have either you or pratish to import the manifest to nautilus i forwarded you the conversion last year about return samples from mccann gerard m sent tuesday july njm pm to poku akwasi a subject re westat cnos for return cdc samples ajn hello akwasi the plates are ready cid ejm gerard mccann developer fisher bioservices thermo fisher scientific njm rothgeb dr rockville md njm phone njm ajn ejm mailto ejm ljk http ljk dissemination distribution or copying of the e mail or the information herein by anyone other than the intended recipient or an employee or agent of a system responsible for delivering the message to the intended recipient is prohibited if you are not the intended recipient please inform the sender and delete all copies from poku akwasi a sent tuesday july njm pm to mccann gerard m subject re westat cnos for return cdc samples ajn are the plates ready from mccann gerard m sent tuesday july njm am to poku akwasi a subject re westat cnos for return cdc samples ajn hello akwasi just to confirm the aliquot location on the plate matches the manifest correct sample id analyte est vol ml box id pos ajn pah njm ajn njm ajn pah njm ajn njm pah ajn njm pah ajn njm ajn pah njm ajn njm ajn pah njm ajn njm ajn pah njm ajn njm ajn pah njm ajn njm ajn pah njm ajn njm ajn pah njm ajn njm ajn pah njm ajn njm ajn pah njm ajn njm ajn pah njm ajn njm ajn pah njm ajn njm ajn pah njm ajn njm ajn pah njm ajn njm ajn pah njm ajn njm ajn pah njm ajn njm ajn pah njm ajn njm ajn pah njm ajn njm ajn pah njm ajn njm ajn pah njm ajn njm ajn pah njm ajn njm ajn pah njm ajn njm gerard mccann developer fisher bioservices thermo fisher scientific njm rothgeb dr rockville md njm phone njm ajn ejm mailto ejm ljk http ljk dissemination distribution or copying of the e mail or the information herein by anyone other than the intended recipient or an employee or agent of a system responsible for delivering the message to the intended recipient is prohibited if you are not the intended recipient please inform the sender and delete all copies from mccann gerard m sent tuesday july njm am to poku akwasi a subject re westat cnos for return cdc samples ajn i'll put them on the plates stand by gerard mccann developer fisher bioservices thermo fisher scientific njm rothgeb dr rockville md njm phone njm ajn ejm mailto ejm ljk http ljk dissemination distribution or copying of the e mail or the information herein by anyone other than the intended recipient or an employee or agent of a system responsible for delivering the message to the intended recipient is prohibited if you are not the intended recipient please inform the sender and delete all copies from poku akwasi a sent tuesday july njm am to mccann gerard m subject re westat cnos for return cdc samples ajn sorry to bother you i need to know how to receive the vials into the plates provided so i can stored them into the njm c from mccann gerard m sent tuesday july njm am to poku akwasi a subject re westat cnos for return cdc samples ajn do you want me to stay connected while you receive or are you good to go gerard mccann developer fisher bioservices thermo fisher scientific njm rothgeb dr rockville md njm phone njm ajn ejm mailto ejm ljk http ljk dissemination distribution or copying of the e mail or the information herein by anyone other than the intended recipient or an employee or agent of a system responsible for delivering the message to the intended recipient is prohibited if you are not the intended recipient please inform the sender and delete all copie ...
# length 562
# require a data pull of pr classification data in precision please route to eto erp as distribution wm precision dear eto can you please pull down our product master from precision into an excel file information from last pull select prprod product replace replace replace ajn ' ' ' pipe ' chr njm ' cr ' chr njm ' lf ' ajn replace replace replace ajn ' ' ' pipe ' chr njm ' cr ' chr njm ' lf ' ajn p njm dev prod prcoor coo p njm dev pr schb pcccmod ajn replace replace replace p njm dev pr schb cmcds njm ' ' ' pipe ' chr njm ' cr ' chr njm ' lf ' ajn replace replace replace p njm dev pr schb cmcds njm ' ' ' pipe ' chr njm ' cr ' chr njm ' lf ' ajn p njm dev pr hts pcccmod ajn replace replace replace p njm dev pr hts cmcds njm ' ' ' pipe ' chr njm ' cr ' chr njm ' lf ' ajn replace replace replace p njm dev pr hts cmcds njm ' ' ' pipe ' chr njm ' cr ' chr njm ' lf ' ajn eccn us pececcn us eccn eccn desc us eccdesc us desc eccn eu pececcn eu eccn eccn desc eu eccdesc eu desc from p njm dev xmprod njm ajn left outer join select u pccprod pccgroup pcccmod ajn from p njm dev xmprcc njm ajn left outer join p njm dev xmcmod njm ajn on p njm dev cm us u client 'tgl' and p njm dev cm us u cmgroup 'hts' and p njm dev cm us u cmcmod p njm dev pr hts pcccmod where p njm dev pr hts u client 'fus' and p njm dev pr hts u pccgroup 'hts' ajn on p njm dev pr hts u pccprod p njm dev prod prprod left outer join select u pccprod pccgroup pcccmod ajn from p njm dev xmprcc njm ajn left outer join p njm dev xmcmod njm ajn on p njm dev cm ca u client 'tgl' and p njm dev cm ca u cmgroup 'schb' and p njm dev cm ca u cmcmod p njm dev pr schb pcccmod where p njm dev pr schb u client 'fus' and p njm dev pr schb u pccgroup 'schb' ajn on p njm dev pr schb u pccprod p njm dev prod prprod left outer join p njm dev xmprec njm eccn eu on eccn eu u client 'fus' and eccn eu u pecprod p njm dev prod u prprod and eccn eu u pecgroup 'eu' left outer join p njm dev xmeccn njm eccn desc eu on eccn desc eu u client 'tgl' and eccn desc eu u ecceccn eccn eu pececcn left outer join p njm dev xmprec njm eccn us on eccn us u client 'fus' and eccn us u pecprod p njm dev prod u prprod and eccn us u pecgroup 'us' left outer join p njm dev xmeccn njm eccn desc us on eccn desc us u client 'tgl' and eccn desc us u ecceccn eccn us pececcn where p njm dev prod u client 'fus' and p njm dev pr hts pcccmod is not null or p njm dev pr schb pcccmod is not null
# length 427
# freight surcharge update we just received additional discounts from some of our freight carriers therefore we would like to update the freight surcharge rates for each of the freight carriers the current freight surcharge process within gpm allows us to select a freight carrier and a country and enter a new overriding surcharge rate the issue we are running into has to do with selecting a country we want to apply njm surcharge rate for each freight carrier across all countries however there is not an option to select all countries and are therefore forced to pick a specific country we would have to select each individual country and carrier combination to apply the new surcharge rate for a specific carrier on top of this we need to add njm customer exclusions bayer lilly j&j to each of these country carrier combinations right now we are looking at njm carriers priority solutions pdp marken and quickstat i've gone through each freight carrier's pricing tables and counted the countries affected using the current process available within gpm it took me njm minutes to add njm carrier country combination along with the njm excluded customers using the njm minute to enter the data into gpm i've calculated it'll take njm hours to enter all of the data carrier of changes njm min each tot hrs per site x njm sites allentown & mt prospect priority solutions njm min njm hrs njm hrs pdp njm min njm hrs njm hrs marken njm min njm hrs njm hrs quickstat njm min njm hrs njm hrs njm total changes njm total hours the simple solutions would be to have the 'all countries' option available in the country drop down menu which would only take njm hour to input all the data however due to the time to implement such a change we are looking at another option of executing a data change to the tables effected we would be adding njm records to the frieghtsurcharge table and njm countries x njm customer exclusions records to the frieghtsrchexcl table data to be appended to the tables will be provided by not implementing the new freight surcharges we are estimating about njm k per month of lost revenue we would be billing the customer at the lower freight surcharge rates instead of the new increased rates in the meantime we'll also need to submit a gpm enhancement request to get the 'wild card all countries' option added to the drop down so that we don't can eliminate the data changes requests going forward
# length 410
# password mismatch between computer and services hi my problem appeared last time i changed my access password from my computer because it was expiring i did it using ctrl alt delete change password since i have lot of issue to connect especially after i'm connected to vpn for some reason my new password was refused by my computer after njm or njm weeks and it reverted to the old password however it's not the case of online services exchange siebel when i'm connected to vpn all exchange accounts ask for a password outlook skype and refuse my password even if the password works to go on the web service of outlook it is working fine if i'm not on the vpn or company network after a while on the vpn i don't have my emails anymore need authentication and refuse my password and i need to disconnect and restart computer if my windows session is locked i cannot reconnect to my account if on vpn or at tfs site trust relationship with the server was broken apparently i need to restart the computer or disable wifi on my computer randomly i cannot access to my account vpn or siebel usually password wrong apparently then i try new password and old one nothing can unlock it i cannot log on siebel right now sometime the exchange server even online web navigator based is also not accessible the password and or id is wrong or not recognised i cannot connect to lifelink and lot of legacy lifetech websites i cannot change the password with ctrl alt delete if i use my old password still in use by the computer the server refuses it if i use my new password my computer says password incorrect maybe the best is to reset my password would it be possible to restore access and rights associated to my account i am field based and it's quite difficult to work for me when i'm locked out form our company network as field application scientist i am also evaluated on my ability to fill siebel properly and without vpn and or siebel access i'm loosing part of my bonus i don't know if it's related but also since i upgraded to tfs network from lifetech my antivirus symantec endpoint didn't update its virus definition is from njm october njm r njm symantec liveupdate or fixing tool don't solve the problem thanks a lot for your help cheers jc
# length 1989
# length 409
# to be assigned to eto ces as call center genesys ccpulse reports questions and possible issues we have a target to avoid agents pull emails and keep wde distributing them in order to have figures at real time how much emails are being pull or distribute we need to be sure how is being measure this information in some ccpulse reports and if we would be able to include and modify some info report njm ccg email voice agent emails offered is it just the emails distributed by wde or something else emails accepted is it when the agent accept the email in the pop up or something else emails processed i have found here some counting issues e g if you click reply in an email and then cacell it is counting as njm email processed if you click forward in an email is counting as njm processed and if you cancelled this forward is also njm processed puting back an email to the queue is also njm processed would it be possible to have here just completed done emails it would be also nice to have split outbound from inbound emails trasfered what is being measure here i made some transfers to other queues and they are not reflected here new column should it be possible to have a new colum with emails pulled njm ccg email queue entered new emails arriving to the queue transferred from other queues including the suspend ones and completly news should it possible to have this figures splited and not being counted the ones from the suspend queue check moved out stopped processing just emails completed done right it is not being counted emails completed when the agent click reply and there are also completed emails moved out emails moved to a workbin emails transfered to another queue or to the suspended queue emails forwarded same issue here if you click forward in an email is being counted even if you cancelled later on the foward for my understanding here we should have only the transfers as a forward is not an email being out of the queue in queue total number of emails in the queue in procesing total number of emails in teh queue without timer right i was not able to validate it with my tests but it is matching with other queues new column should it be possible to have a new colum with emails pulled
# length 513
# thermofisher sap basware vpn setup setup tunnels for basware we are working on project rudolph it is a new sap hana ajn implementation for finland vaanta site and it is a part of sdg division as part of this project we are implementing procure to pay basware cloud application and basware team want to setup a vpn connection to access following sap application servers ajn mfrd njm a njm development rest of sap application servers under construction technical contact name razvan livanu technical contact phone njm technical contact email ejm project manager name project manager phone project manager phone device infromation thermofisher basware location datacenter aws ireland hardware type sophos utm vpn software njm ip address of vpn external interface njm aws ireland ajn ip address information thermofisher basware networks to be encrypted and accessed through vpn tunnel networks thermofisher domain encryption basware domain encryption thermofisher servers private ip address basware server private ip address hosts njm are more desirable as we do nat on our side tbd ljk ireland ajn connections ports tbd tbd tbd ljk vpn tunnel settings thermofisher basware ike parameters agreed proposals proposed settings ike encryption algorithm please select an option aes njm bit ike authentication algorithm please select an option ajn njm bit ike sa lifetime please select an option njm ajn ike dh group please select an option group njm modp njm authentication method pre shared key to be exchanged via sms to be exchanged via sms ipsec parameters ipsec encryption algorithm please select an option aes njm bit ipsec authentication algorithm please select an option ajn njm bit ipsec sa lifetime please select an option njm ajn ipsec pfs please select an option yes ipsec dh group please select an option group njm modp njm ajn tunnel contact information thermofisher basware technical contact name razvan livanu technical contact phone njm technical contact email ejm project manager name project manager phone project manager phone device infromation thermofisher basware location datacenter aws ireland hardware type sophos utm vpn software njm ip address of vpn external interface njm aws ireland ajn ip address information thermofisher basware networks to be encrypted and accessed through vpn tunnel networks thermofisher domain encryption basware domain encryption thermofisher servers private ip address basware server private ip address hosts njm are more desirable as we do nat on our side ljk ireland ajn connections ports tbd tbd tbd ljk vpn tunnel settings thermofisher basware ike parameters agreed proposals proposed settings ike encryption algorithm please select an option aes njm bit ike authentication algorithm please select an option ajn njm bit ike sa lifetime please select an option njm ajn ike dh group please select an option group njm modp njm authentication method pre shared key to be exchanged via sms to be exchanged via sms ipsec parameters ipsec encryption algorithm please select an option aes njm bit ipsec authentication algorithm please select an option ajn njm bit ipsec sa lifetime please select an option njm ajn ipsec pfs please select an option yes ipsec dh group please select an option group njm modp njm
# length 522
# site information db requires update hi team please go through the below given details user is looking for update in particular site please let me know if you need any other information regarding the same thank you arvind from travis nick sent wednesday may njm pm to malone ken ejm cc kumar arvind ejm subject re ajn site information db requires update that answers my question so thank you ken arvind the desktop support group for the us sugarland tx site profile needs to be updated to eto ees ds houston thank you nick travis systems administrator ii advanced computing services it operations center thermo fisher scientific njm business center drive pittsburgh pa njm itoc ajn ejm from malone ken sent wednesday may njm am to travis nick cc kumar arvind subject re ajn site information db requires update nick sugar land no longer has a desktop support group all call were being routed to the houston desktop support group thanks ken sent from my iphone on may njm at njm am travis nick ejm wrote hello this incident was opened almost njm months ago with the change in servicenow naming convention yes that group is no longer valid even with that the given group that was showing was incorrect at the time which is one of the reasons i opened up the incident the desktop support group is what needs updated i do not know what it needs updated to i just know the current listing is incorrect ken malone ken what is the desktop support group for sugarland thank you nick travis systems administrator ii advanced computing services it operations center thermo fisher scientific njm business center drive pittsburgh pa njm itoc ajn ejm from kumar arvind sent wednesday may njm am to travis nick subject re ajn site information db requires update hi nick as i checked for the given group it is in deactivated state kindly let us know what exactly do you want us to update in it thank you arvind from thermo fisher global it mailto ejm sent monday may njm pm to ejm kumar ajn ejm subject ajn has been updated global site information db requires update image njm png click here to view incident ajn updated by amer eric levy last worklog update ljg djt njm edt eric levy work notes routing to servicenow administrators for assistance db needs update as per user's notes pls assist ljg djt njm edt ken malone work notes please forward to appropriate group for adding to designated desktop support group km ljg djt njm edt nick travis work notes assigning to appropriate team to update their site profile last additional comments update ljg djt njm edt ken malone additional comments please send info ejm regarding this update thx km state new requester name nick travis location us pittsburgh information db pa campbells run short description global site requires update description field that needs updated desktop support group currently it is epm desktop sugarland tx which is not a valid servicenow group site code ussug click here to go to self service it service catalog ref msg njm
# length 692
# fw update routetabel bestanden update routing databasefiles received from ejm from winfried van vessem mailto ejm sent woensdag njm april njm to sauer dieter ejm didden sonja ejm cc pels frank ejm kespi jean michel ejm erwin willemsen ejm subject fw update routetabel bestanden update routing databasefiles dear all dpd send us below message regarding the requested update routing databasefiles per monday njm may njm please upload the new routingfile into your system and send us a test label by email thank you in advance met vriendelijke groet kind regards ljg winfried van vessem key account manager mainfreight forwarding netherlands industriestraat njm gd 's heerenberg the netherlands chamber of commerce no njm t njm m njm e ejm mailto ejm cid ejm cid ejm ljk cid ejm mainfreight ljk cid ejm ljk https www ljk cid ejm ljk https www ljk van customer it mailto ejm verzonden dinsdag njm april njm aan customer it onderwerp update routetabel bestanden update routing databasefiles update routetabel bestanden update routing databasefiles routetabel update cid ejm dear business associate dpd's new routing database will become effective on monday njm may njm included in the attachment is the routing database for self developers valid for shipments to all depots in the netherlands you can find the current version of the routing database in the header information of each routing database file this includes two indicators version shows the start date of the routing database expiration shows the expiry date of the routing database the new routing database contains the following values version njm expiration njm use this information to help plan future updates please note the update involves nationwide changes to our routing areas if you do not update the route table in good time your parcels are at greater risk of being sent on the wrong route which may mean that we are unable to achieve our delivery times it is important that you import the individual files into the wms software on monday njm may njm to check whether the import has been successful we would like you to send us a test label for nl postcode ajn which has been changed in the new routing database scan the label and send it by email to ejm mailto ejm the update is also available for download from ljk here you can find the update files for your depot if you are not the person in your company responsible for this action please forward this email to the relevant it contact if you have any questions please contact customer it beste relatie op maandag njm mei njm gaat de nieuwe routetabel van dpd in in de bijlage vind je de routetabel voor zelfontwikkelaars die geldig is voor zendingen voor alle depots in nederland je kunt de huidige versie van de routetabel vinden in de header informatie van ieder routetabelbestand daarin staan twee indicatoren version toont de begindatum van de routetabel expiration toont de einddatum van de routetabel de nieuwe routetabel bevat de volgende waarden version njm expiration njm gebruik deze gegevens voor het plannen van toekomstige updates let op de update betreft landelijke wijzigingen in de gebiedsherindeling indien je de routetabel niet tijdig update verhoogt dat de kans dat je pakketten een verkeerde kant worden opgestuurd het risico bestaat dan dat we de levertijden niet halen het is belangrijk dat je de afzonderlijke bestanden op maandag njm mei njm inleest in je wms software om te controleren of dit goed is gegaan ontvangen wij graag een testlabel van een nl postcode ajn die in de nieuwe routetabel is veranderd scan het label in en mail het naar ejm mailto ejm de update is ook beschikbaar op ljk op deze locatie staat per depot jou bestand klaar ben je niet degene binnen jouw bedrijf die hiervoor verantwoordelijk is dan vragen wij je om deze mail door te sturen naar de juiste it contactpersoon heb je vragen neem dan contact op met customer it best regards met vriendelijke groet customer it customer it integration njm ejm mailto ejm cid ejm dpd neth ...
# length 550
# ...
# length 1244
# please assign ticket to location frederick local it team hi team could you please provide correct ip addresses of printers in lsg sap ajn system dev dev type spool servers location or message sap information comments active inactive currect ip address exact location commented by ajn l ajn prd njm d njm frederick new bldg west njm ajn l ajn prd njm d njm frederick njm west ajn l ajn prd njm d njm frederick njm ajn l ajn prd njm d njm frederick distribution pack station ajn l ajn prd njm d njm frederick distribution center njm ajn l ajn prd njm d njm frederick distribuiton center njm ajn l ajn prd njm d njm ip njm frederick pack station ajn l ajn prd njm d njm ip njm attn amit bhaisare frederick njm pack station ajn l ajn prd njm d njm frederickson joshua ajn l ajn prd njm d njm ljk race bradford fred test printer ajn l ajn prd njm d njm old ljk bradford fred test printer new njm ajn l ajn prd njm d njm ljk race bradford fred test printer ajn l ajn prd njm d njm frederick old ljk new njm ajn l ajn prd njm d njm old ljk new ip njm ajn l ajn prd njm d njm old ljk new njm ajn l ajn prd njm d njm ljk ajn l ajn prd njm d njm old ljk new njm ajn l ajn prd njm d njm ip njm attn brad race insram shah ajn l ajn prd njm d njm p njm attn brad race insram shah ajn l ajn prd njm d njm ip njm contact bradford race ajn l ajn prd njm d njm ip njm contact bradford race ajn l ajn prd njm d njm ip njm network name ajn l ajn prd njm d njm old njm new njm ajn l ajn prd njm d njm ip njm ajn l ajn prd njm d njm old njm new njm ajn l ajn prd njm d njm old njm new njm ajn l ajn prd njm d njm old njm new njm ajn l ajn prd njm d njm old njm new njm ajn l ajn prd njm d njm old njm new njm ajn l ajn prd njm d njm old njm new njm ajn l ajn prd njm d njm old njm new njm ajn l ajn prd njm d njm old njm new njm ajn l ajn prd njm d njm old njm new njm ajn l ajn prd njm d njm old njm new njm ajn l ajn prd njm d njm old njm new njm ajn l ajn prd njm d njm old njm new njm ajn l ajn prd njm d njm old njm new njm ajn l ajn prd njm d njm old njm new njm ajn l ajn prd njm d njm old njm new njm ajn l ajn prd njm d njm old njm new njm ajn l ajn prd njm d njm ip njm ajn l ajn prd njm d njm ajn single line packs near primers ajn l ajn prd njm d njm ajn single line packs near primers ajn l ajn prd njm d njm ajn single line packs near primers ajn l ajn prd njm d njm ajn l ajn prd njm d njm ajn l ajn prd njm d njm ajn l ajn prd njm d njm ajn l ajn prd njm d njm ajn l ajn prd njm d njm ajn l ajn prd njm d njm ajn l ajn prd njm d njm ajn l ajn prd njm d njm ajn l ajn prd njm d njm ajn l ajn prd njm d njm ljk ajn l ajn prd njm d njm old ljk new njm ajn l ajn prd njm d njm ip njm network name ajn l ajn prd njm d njm ip njm ajn l ajn prd njm d njm ajn l ajn prd njm d njm ip njm attn eric sinclair ajn l ajn prd njm d njm ip njm ajn l ajn prd njm d njm ip njm attn amit bhaisare pack station njm ajn l ajn prd njm d njm ajn l ajn prd njm d njm ajn l ajn prd njm d njm ajn l ajn prd njm d njm ajn l ajn prd njm d njm ajn l ajn prd njm d njm ajn l ajn prd njm d njm ajn l ajn prd njm d njm ip njm ajn l ajn prd njm d njm ajn l ajn prd njm d njm ajn l ajn prd njm d njm ajn l ajn prd njm d njm old ljk new njm ajn l ajn prd njm d njm old ljk new njm ajn l ajn prd njm d njm old ljk new njm ajn l ajn prd njm d njm ljk ajn l ajn prd njm d njm brad race host ajn ip njm ajn l ajn prd njm d njm ajn l ajn prd njm d njm ajn l ajn prd njm d njm ip njm replaces ajn new ip njm ajn l ajn prd njm d njm ip njm attn brad race replaces ajn l ajn prd njm d njm ip njm attn brad race ajn l ajn prd njm d njm ip njm attn brad race ajn l ajn prd njm d njm ip njm attn brad race ajn l ajn prd njm d njm ip njm attn brad race ajn l ajn prd njm d njm ip njm attn brad race ajn l ajn prd njm d njm ip njm attn brad race ajn l ajn prd njm d njm ip njm attn brad race replaces ajn l ajn prd njm d njm ip njm attn brad race replaces ajn l ajn prd njm d njm ip njm attn brad race replaces ajn l ajn prd njm d njm ip njm attn brad  ...
# length 540
# can you help me gain access the shared e mail ejm can you help me gain access the shared e mail ejm i need access for salesforce parts ordering the salesforce parts e mail address is going on line this week from burke dick sent monday june njm pm to del mar jonathan ejm cc goshert mark a ejm wasley shana l ejm subject fw ajn use this form to request access to available shared mailboxes or to modify current access hi jonathan can you help me gain access the shared e mail ejm i need access for salesforce parts ordering the salesforce parts e mail address is going on line this week regards richard burke global parts coordinator customer service rep thermo fisher scientific flat sheet gauging web applications njm research drive dock c wilmington ma ajn tel ajn ejm from goshert mark a sent monday june njm pm to burke dick cc wasley shana l subject re ajn use this form to request access to available shared mailboxes or to modify current access hi dick please contact jonathan delmar in email as he requested you were on the list for mailbox sharing let me know when resolved or if you have issues we can't move on with training the fe's until resolved thanks mark from burke dick sent thursday june njm am to goshert mark a subject re ajn use this form to request access to available shared mailboxes or to modify current access hi mark i added the mailbox but i get this error when i try to open the box in outlook from goshert mark a sent tuesday june njm pm to burke dick subject fw ajn use this form to request access to available shared mailboxes or to modify current access hi dick below is the message with instructions for setting up your new mailbox for parts best regards mark from it service desk mailto ejm sent tuesday april njm pm to goshert mark a cc lynch brian e deraimo okey small renee delaney marti subject ajn use this form to request access to available shared mailboxes or to modify current access hello you have been granted access to ejm please allow ajn hours for the changes to take effect and follow instructions below to add the mailbox if you have any issues adding the mailbox please contact me directly to assist you please confirm that you have access thank you & best regards ejm service desk ajn analyst please use reply all if you need to reply back to add the shared mailbox njm close outlook njm control panel click mail or mail ajn njm click e mail accounts button njm select the e mail tab njm highlight your mailbox click the change button njm click the more settings button njm select the advance tab njm click the add button njm type the shared e mail address njm click the apply and ok buttons njm click next finish and close buttons number ajn short description use this form to request access to available shared mailboxes or to modify current access details fyi the above document link for standard naming convention did not work so i couldn't access to get details ref msg njm
# length 561
# please assign to latam e njm mdm support por favor arrumar o cadastro dos itens abaixo ajn estender o cadastro para a filial njm e manter obsoleto na njm mensagem intermitente evos vendido pela ajn amep njm estender o cadastro para a filial njm e manter obsoleto na njm mensagem intermitente evos vendido pela ajn amep njm estender o cadastro para a filial njm e manter obsoleto na njm mensagem intermitente evos vendido pela ajn amep njm estender o cadastro para a filial njm e manter obsoleto na njm mensagem intermitente evos vendido pela ajn amep njm colocar o no stoking type na filial njm manter ativo apenas na filial njm mensagem intermitente evos vendido pela ajn amep njm estender o cadastro para a filial njm e manter obsoleto na njm mensagem intermitente evos vendido pela ajn amep njm estender o cadastro para a filial njm e manter obsoleto na njm mensagem intermitente evos vendido pela ajn amep njm estender o cadastro para a filial njm e manter obsoleto na njm mensagem intermitente evos vendido pela ajn amep njm estender o cadastro para a filial njm e manter obsoleto na njm mensagem intermitente evos vendido pela ajn amep njm estender o cadastro para a filial njm e manter obsoleto na njm mensagem intermitente evos vendido pela ajn amep njm estender o cadastro para a filial njm e manter obsoleto na njm mensagem intermitente evos vendido pela ajn amep njm estender o cadastro para a filial njm e manter obsoleto na njm mensagem intermitente evos vendido pela ajn amep njm estender o cadastro para a filial njm e manter obsoleto na njm mensagem intermitente evos vendido pela ajn amep njm estender o cadastro para a filial njm e manter obsoleto na njm mensagem intermitente evos vendido pela ajn amep njm estender o cadastro para a filial njm e manter obsoleto na njm mensagem intermitente evos vendido pela ajn amep njm estender o cadastro para a filial njm e manter obsoleto na njm mensagem intermitente evos vendido pela ajn amep njm estender o cadastro para a filial njm e manter obsoleto na njm mensagem intermitente evos vendido pela ajn amep njm estender o cadastro para a filial njm e manter obsoleto na njm mensagem intermitente evos vendido pela ajn amep njm estender o cadastro para a filial njm e manter obsoleto na njm mensagem intermitente evos vendido pela ajn amep njm estender o cadastro para a filial njm e manter obsoleto na njm mensagem intermitente evos vendido pela ajn amep njm estender o cadastro para a filial njm e manter obsoleto na njm mensagem intermitente evos vendido pela ajn amep njm estender o cadastro para a filial njm e manter obsoleto na njm mensagem intermitente evos vendido pela ajn amep njm colocar o no stoking type na filial njm manter ativo apenas na filial njm mensagem intermitente evos vendido pela ajn amepcfb estender o cadastro para a filial njm e manter obsoleto na njm mensagem intermitente evos vendido pela ajn amepcfg estender o cadastro para a filial njm e manter obsoleto na njm mensagem intermitente evos vendido pela ajn amex njm estender o cadastro para a filial njm colocar obsoleto e manter obsoleto na njm memsagem intermitente bloq na origem para compra ajn estender o cadastro para a filial njm e manter obsoleto na njm mensagem intermitente evos vendido pela l njm
# length 405
# forward emails please forward all emails for ejm to her manager ejm i have hr and legal approval below we need to have this done as soon as possible thank you from a practical perspective did we communicate to the employee that her supervisor will be reading her email if so i am ok with it john sabo vice president and general counsel customer channels group thermo fisher scientific njm industry drive pittsburgh pa njm phone njm ajn mobile njm ajn ejm ljk from beck donna l sent tuesday february njm pm to sabo john b ejm subject fw ajn general request please forward emails for stacy steel to her manager lonnie davis john please see debbie's note below thanks donna from jarrard debbie h sent tuesday february njm pm to beck donna l ejm subject fw ajn general request please forward emails for stacy steel to her manager lonnie davis hi donna i am so sorry to bother you stacy steele is out on maternity leave and her manager lonnie davis needs to answer emails from customers could we please get someone to approve this one going forward should i send these to you or is there another way we should be handling these requests thank you debbie from wallace erin sent tuesday february njm am to jarrard debbie h ejm subject fw ajn general request please forward emails for stacy steel to her manager lonnie davis hi debbie is there any way you can assist with this thanks erin from thermo fisher global it mailto ejm sent tuesday february njm am to wallace erin davis lonnie w cc duarte leonardo subject ajn general request please forward emails for stacy steel to her manager lonnie davis hello lonnie and erin as i indicate on my email stacy steel still appears active in our server therefore we required also the approval of a general counsel regards leonardo duarte number ajn short description general request please forward emails for stacy steel to her manager lonnie davis details stacy steel ejm is on maternity leave and her emails need to be forwarded to her manager lonnie davis ejm we have hr approval in the email below hi debbie can you have stacy's emails forwarded to lonnie thanks erin erin wallace hr manager customer channels group thermo fisher scientific njm turnberry dr hanover park il njm tel njm ajn mobile njm ajn ejm ljk ref msg njm
# the strings are pickled

# %% [markdown]
# # Text Vectorization (NOT Needed for This Project)

# %%
# import the dependencies
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score

# %%
# vectorize the texts
vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(full_descriptions_ready)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-fd6037f8dd6b> in <module>
#       1 # vectorize the texts
#       2 vectorizer = TfidfVectorizer(stop_words='english')
# ----> 3 X = vectorizer.fit_transform(full_descriptions_ready)
#
# NameError: name 'full_descriptions_ready' is not defined

# %%
# # a manual approach
# wordCount = defaultdict(int)
# clean_rows = []
# for index, row in data.iterrows():
#     k = row['Subject']
#     if(isinstance(k, basestring)):
#         clean_rows.append(k)
#         for w in k.split():
#             wordCount[w] += 1
#     else:
#         clean_rows.append('')
# punctuation = set(string.punctuation)
# stemmed = []
# for k in clean_rows:
#     words = []
#     r = ''.join([c for c in k.lower() if not c in punctuation])
#     stemmed.append(r)
# data['cleaned'] = stemmed

# punctuation = set(string.punctuation)
# stemmed = []
# for k in clean_rows:
#     words = []
#     r = ''.join([c for c in k.lower() if not c in punctuation])
#     stemmed.append(r)
# data['cleaned'] = stemmed

# cleaned = []
# def remove_non_ascii(words):
#     """Remove non-ASCII characters from list of tokenized words"""
#     new_words = []
#     for word in words:
#         new_word = unicodedata.normalize('NFKD', word).encode('ascii', 'ignore').decode('utf-8', 'ignore')
#         new_words.append(new_word)
#     return new_words

# def replace_numbers(words):
#     """Replace all interger occurrences in list of tokenized words with textual representation"""
#     p = inflect.engine()
#     new_words = []
#     for word in words:
#         if word.isdigit():
#             new_word = p.number_to_words(word)
#             new_words.append(new_word)
#         else:
#             new_words.append(word)
#     return new_words

# def remove_stopwords(words):
#     """Remove stop words from list of tokenized words"""
#     new_words = []
#     for word in words:
#         if word not in stopwords.words('english'):
#             new_words.append(word)
#     return new_words

# def stem_words(words):
#     """Stem words in list of tokenized words"""
#     stemmer = LancasterStemmer()
#     stems = []
#     for word in words:
#         stem = stemmer.stem(word)
#         stems.append(stem)
#     return stems

# def lemmatize_verbs(words):
#     """Lemmatize verbs in list of tokenized words"""
#     lemmatizer = WordNetLemmatizer()
#     lemmas = []
#     for word in words:
#         lemma = lemmatizer.lemmatize(word, pos='v')
#         lemmas.append(lemma)
#     return lemmas

# def normalize(words):
#     words = remove_non_ascii(words)
#     words = replace_numbers(words)
#     words = remove_stopwords(words)
#     #words = stem_words(words)
#     words =lemmatize_verbs(words)
#     return words

# for item in data['cleaned']:
#     words = word_tokenize(item)
#     words = normalize(words)
#     cleaned.append(words)

# str_clean = []
# for x in cleaned:
#     str1 = ' '.join(x)
#     str_clean.append(str(str1))

# %%
# option 2: use a RNN encoder
# code from https://pytorch.org/tutorials/intermediate/seq2seq_translation_tutorial.html?fbclid=IwAR0A9VArVExCiqW4N0xpDh42z1Mt8Ov0sDsjNhYnD_RuizJf6i3EioibhI8
from __future__ import unicode_literals, print_function, division
from io import open
import unicodedata
import string
import re
import random

import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import time
import math

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# create a word to number mapping
SOS_token = 0
EOS_token = 1


class Stats:
    def __init__(self, name):
        self.name = name
        self.word2index = {}
        self.word2count = {}
        self.index2word = {0: "SOS", 1: "EOS"}
        self.n_words = 2  # Count SOS and EOS

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.n_words
            self.word2count[word] = 1
            self.index2word[self.n_words] = word
            self.n_words += 1
        else:
            self.word2count[word] += 1
            
    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

eng_stats = Stats('eng')
for text in full_descriptions_ready:
    eng_stats.addSentence(text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-f0c7d9f3706b> in <module>
#      26
#      27 eng_stats = Stats('eng')
# ---> 28 for text in full_descriptions_ready:
#      29     eng_stats.addSentence(text)
#
# NameError: name 'full_descriptions_ready' is not defined

# %%
# prepare the data
def indexesFromSentence(lang, sentence):
    return [lang.word2index[word] for word in sentence.split(' ')]

def tensorPairFromSentence(lang, sentence):
    indexes = indexesFromSentence(lang, sentence)
    indexes.append(EOS_token)
    t = torch.tensor(indexes, dtype=torch.long, device=device).view(-1, 1)
    return (t, t)

# %%
# define the encoder and decoder RNN
class EncoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(EncoderRNN, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embeddi
        ng(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)

    def forward(self, input, hidden):
        embedded = self.embedding(input).view(1, 1, -1)
        output = embedded
        output, hidden = self.gru(output, hidden)
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)
    
class AttnDecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size, dropout_p=0.1, max_length=MAX_LENGTH):
        super(AttnDecoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.dropout_p = dropout_p
        self.max_length = max_length

        self.embedding = nn.Embedding(self.output_size, self.hidden_size)
        self.attn = nn.Linear(self.hidden_size * 2, self.max_length)
        self.attn_combine = nn.Linear(self.hidden_size * 2, self.hidden_size)
        self.dropout = nn.Dropout(self.dropout_p)
        self.gru = nn.GRU(self.hidden_size, self.hidden_size)
        self.out = nn.Linear(self.hidden_size, self.output_size)

    def forward(self, input, hidden, encoder_outputs):
        embedded = self.embedding(input).view(1, 1, -1)
        embedded = self.dropout(embedded)

        attn_weights = F.softmax(
            self.attn(torch.cat((embedded[0], hidden[0]), 1)), dim=1)
        attn_applied = torch.bmm(attn_wei
                                 ghts.unsqueeze(0),
                                 encoder_outputs.unsqueeze(0))

        output = torch.cat((embedded[0], attn_applied[0]), 1)
        output = self.attn_combine(output).unsqueeze(0)

        output = F.relu(output)
        output, hidden = self.gru(output, hidden)

        output = F.log_softmax(self.out(output[0]), dim=1)
        return output, hidden, attn_weights

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %%
# training process
teacher_forcing_ratio = 0.5

def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)


def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))

def train(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion, max_length=MAX_LENGTH):
    encoder_hidden = encoder.initHidden()

    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    input_length = input_tensor.size(0)
    target_length = target_tensor.size(0)

    encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

    loss = 0

    for ei in range(input_length):
        encoder_output, encoder_hidden = encoder(
            input_tensor[ei], encoder_hidden)
        encoder_outputs[ei] = encoder_output[0, 0]

    decoder_input = torch.tensor([[SOS_token]], device=device)

    decoder_hidden = encoder_hidden

    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    if use_teacher_forcing:
        # Teacher forcing: Feed the target as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            loss += criterion(decoder_output, target_tensor[di])
            decoder_input = target_tensor[di]  # Teacher forcing

    else:
        # Without teacher forcing: use its own predictions as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            topv, topi = decoder_output.topk(1)
            decoder_input = topi.squeeze().detach()  # detach from history as input

            loss += criterion(decoder_output, target_tensor[di])
            if decoder_input.item() == EOS_token:
                break

    loss.backward()

    encoder_optimizer.step()
    decoder_optimizer.step()

    return loss.item() / target_length

def trainIters(encoder, decoder, sentences, n_iters, print_every=1000, plot_every=100, learning_rate=0.01):
    start = time.time()
    plot_losses = []
    print_loss_total = 0  # Reset every print_every
    plot_loss_total = 0  # Reset every plot_every

    encoder_optimizer = optim.SGD(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate)
    training_pairs = [tensorPairFromSentence(random.choice(sentences))
                      for i in range(n_iters)]
    criterion = nn.NLLLoss()

    for iter in range(1, n_iters + 1):
        training_pair = training_pairs[iter - 1]
        input_tensor = training_pair[0]
        target_tensor = training_pair[1]

        loss = train(input_tensor, target_tensor, encoder,
                     decoder, encoder_optimizer, decoder_optimizer, criterion)
        print_loss_total += loss
        plot_loss_total += loss

        if iter % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print_loss_total = 0
            print('%s (%d %d%%) %.4f' % (timeSince(start, iter / n_iters),
                                         iter, iter / n_iters * 100, print_loss_avg))

        if iter % plot_every == 0:
            plot_loss_avg = plot_loss_total / plot_every
            plot_losses.append(plot_loss_avg)
            plot_loss_total = 0
    showPlot(plot_losses)
    
# call the helper functions to train on the actual data
hidden_size = 256
encoder1 = EncoderRNN(eng_stats.n_words, hidden_size).to(device)
attn_decoder1 = AttnDecoderRNN(hidden_size, eng_stats.n_words, dropout_p=0.1).to(device)

trainIters(encoder1, attn_decoder1, full_descriptions_ready, len(full_descriptions_ready)*0.8, print_every=5000)

# %%
MAX_LENGTH
# Out:
# 3025

# %% [markdown]
# # Vector Clustering

# %%
# K-means approach

# define the cluster number
true_k = 7

# set up the model. try 10 random centroid seeds, with 300 iteration for each
model = KMeans(n_clusters=true_k, init='k-means++', max_iter=300, n_init=10)
model.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=7, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
# examine the results
print("Top terms per cluster:")
order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()
for i in range(true_k):
    print("Cluster %d:" % i),
    for ind in order_centroids[i, :10]:
        print(' %s' % terms[ind]),
    print
# Out:
# Top terms per cluster:
# Cluster 0:
#  phone
#  desk
#  headset
#  number
#  new
#  extension
#  avaya
#  need
#  set
#  calls
# Cluster 1:
#  office
#  2013
#  365
#  microsoft
#  upgrade
#  2010
#  version
#  ms
#  install
#  plus
# Cluster 2:
#  need
#  new
#  computer
#  request
#  account
#  link
#  printer
#  team
#  add
#  assign
# Cluster 3:
#  laptop
#  new
#  need
#  loaner
#  install
#  software
#  battery
#  installed
#  request
#  docking
# Cluster 4:
#  sap
#  gui
#  pr1
#  c11
#  access
#  need
#  installation
#  user
#  d50
#  new
# Cluster 5:
#  access
#  need
#  drive
#  folder
#  link
#  provide
#  shared
#  request
#  grant
#  read
# Cluster 6:
#  email
#  list
#  distribution
#  add
#  address
#  emails
#  group
#  remove
#  change
#  need

# %%
# make predictions
print("\n")
print("Prediction")
Y = vectorizer.transform(["email not working"])
prediction = model.predict(Y)
print(prediction)

Y = vectorizer.transform(["can't access the website"])
prediction = model.predict(Y)
print(prediction)
# Out:
# Prediction
# [6]
# [5]

# %%
from collections import Counter
print(Counter(model.labels_))
# Out:
# Counter({2: 49895, 5: 10431, 6: 4923, 3: 4078, 0: 3348, 4: 2963, 1: 2084})

# %%
# Out:
# Collecting collections-extended
#   Downloading https://files.pythonhosted.org/packages/e6/bb/917ec8f030be3da7a4610f98dc6fc46a2d701433a1e6f82905f0cbd1be3f/collections_extended-1.0.2-py2.py3-none-any.whl
# Requirement already satisfied: setuptools in ./venv/lib/python3.7/site-packages (from collections-extended) (40.8.0)
# Installing collected packages: collections-extended
# Successfully installed collections-extended-1.0.2
# WARNING: You are using pip version 19.2.1, however version 19.2.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# Out:
# 77805
