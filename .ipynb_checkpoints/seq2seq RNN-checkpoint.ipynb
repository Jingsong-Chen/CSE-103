# %% [markdown]
# # Preparing Data¶

# %%
import torch
import torch.nn as nn
import torch.optim as optim

from torchtext.datasets import TranslationDataset, Multi30k
from torchtext.data import Field, BucketIterator

import spacy

import random
import math
import time
import pickle
import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-97d32c199746> in <module>
#       3 import torch.optim as optim
#       4
# ----> 5 from torchtext.datasets import TranslationDataset, Multi30k
#       6 from torchtext.data import Field, BucketIterator
#       7
#
# ModuleNotFoundError: No module named 'torchtext'

# %%
spacy_en = spacy.load('en')

# %%
# define the path variables
BASE_DIR = os.path.abspath('')
DATA_DIR = os.path.join(BASE_DIR, 'data')
REQUEST_DATA_PATH = os.path.join(DATA_DIR, 'clean_requests.pickle')
TRAIN_EN_PATH = os.path.join(DATA_DIR, 'multi30k/train.en')
VAL_EN_PATH = os.path.join(DATA_DIR, 'multi30k/val.en')
TEST_EN_PATH = os.path.join(DATA_DIR, 'multi30k/test2016.en')
# TRAIN_SRC_PATH = os.path.join(DATA_DIR, 'multi30k/train.src')
# VAL_SRC_PATH = os.path.join(DATA_DIR, 'multi30k/val.src')
# TEST_SRC_PATH = os.path.join(DATA_DIR, 'multi30k/test2016.src')
TRAIN_TOKEN_PATH = os.path.join(DATA_DIR, 'tokens.pickle')

# %%
# set the random seeds for deterministic results
SEED = 1234

random.seed(SEED)
torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

# %%
def tokenize_en(text):
    """
    Tokenizes English text from a string into a list of strings (tokens)
    """
    return [tok.text for tok in spacy_en.tokenizer(text)]

# %%
# we want the vector representation of the texts, not translation
SRC = Field(tokenize = tokenize_en, 
            init_token = '<sos>', 
            eos_token = '<eos>', 
            lower = True)

TRG = Field(tokenize = tokenize_en, 
            init_token = '<sos>', 
            eos_token = '<eos>', 
            lower = True)

# %%
# load the text data
requests = pickle.load(open(REQUEST_DATA_PATH, "rb"))

# devide the text data into training, validating, and testing set
random.shuffle(requests)
request_number = len(requests)
test = requests[:int(request_number*0.03)]
validation = requests[int(request_number*0.03):int(request_number*0.06)]
train = requests[int(request_number*0.06):]

# save the data for Multi30k
with open(TEST_EN_PATH, 'w') as target:
    for t in test:
        line = t + '\n'
        target.write(line)
target.close()
with open(VAL_EN_PATH, 'w') as target:
    for v in validation:
        line = v + '\n'
        target.write(line)
target.close()
with open(TRAIN_EN_PATH, 'w') as target:
    for t in train:
        line = t + '\n'
        target.write(line)
target.close()

# %%
# tokenize the text
train_data, valid_data, test_data = Multi30k.splits(exts = ('.en', '.en'), 
                                                    fields = (SRC, TRG), root=DATA_DIR)

print(f"Number of training examples: {len(train_data.examples)}")
print(f"Number of validation examples: {len(valid_data.examples)}")
print(f"Number of testing examples: {len(test_data.examples)}")

# with open(TRAIN_TOKEN_PATH, 'wb') as f:
#     pickle.dump(train_data, f)
# f.close()
# vars(test_data[0])
# Out:
# Number of training examples: 72984
# Number of validation examples: 2329
# Number of testing examples: 2329

# %%
# build the vocabulary from the training set
SRC.build_vocab(train_data, min_freq = 2)
TRG.build_vocab(train_data, min_freq = 2)
print(f"Unique tokens in request vocabulary: {len(TRG.vocab)}")
vars(TRG.vocab)
# Out:
# Unique tokens in request vocabulary: 34282
# {'freqs': Counter({'account': 6803,
#           'export': 356,
#           'for': 50500,
#           'uk': 815,
#           'and': 45593,
#           'us': 2286,
#           'accounts': 1055,
#           'from': 15704,
#           'oracle': 689,
#           'r': 644,
#           'njm': 83388,
#           'i': 47206,
#           'want': 1332,
#           'to': 128976,
#           'review': 665,
#           'the': 92706,
#           'see': 2902,
#           'if': 5301,
#           'any': 3416,
#           'reps': 87,
#           'assigned': 1174,
#           'need': 28934,
#           'updated': 1313,
#           'please': 40320,
#           'assign': 6130,
#           'doug': 102,
#           'jensen': 25,
#           'new': 18356,
#           'genesys': 1814,
#           'agent': 1154,
#           'request': 12529,
#           'plz': 54,
#           'it': 19330,
#           'eas': 741,
#           'call': 1584,
#           'center': 1766,
#           'install': 4834,
#           'on': 24395,
#           'pc': 3423,
#           'because': 1264,
#           'angela': 104,
#           'has': 7299,
#           'not': 17119,
#           'yet': 256,
#           'been': 3802,
#           'migrated': 222,
#           'she': 2230,
#           'is': 31321,
#           'a': 37500,
#           'cintrix': 1,
#           'thin': 41,
#           'client': 1236,
#           'acces': 267,
#           'common': 209,
#           'folder': 3622,
#           'ajn': 44229,
#           'gbs': 55,
#           'bud': 13,
#           'finance': 816,
#           'ljk': 7871,
#           'z': 324,
#           'aig': 267,
#           't&e': 31,
#           'access': 27135,
#           'have': 18403,
#           'store': 161,
#           'there': 3134,
#           'documentations': 7,
#           'yearly': 19,
#           'power': 995,
#           'maintenance': 449,
#           'schedule': 511,
#           'december': 274,
#           'at': 6599,
#           'tijuana': 130,
#           'site': 4913,
#           'route': 1260,
#           'gis': 1769,
#           'nacrglobaltelephony': 6,
#           'team': 8503,
#           'this': 22285,
#           'was': 5219,
#           'approved': 507,
#           'with': 13851,
#           'urgent': 814,
#           'change': 5211,
#           'number': 4306,
#           'cab': 45,
#           'meeting': 1705,
#           'today': 854,
#           'by': 4956,
#           'corporate': 408,
#           'lpd': 219,
#           'lpe': 27,
#           'end': 1021,
#           'of': 24219,
#           'year': 457,
#           'preventative': 16,
#           'sub': 233,
#           'station': 1465,
#           "'s": 6308,
#           'scheduled': 339,
#           'starting': 828,
#           'dec': 231,
#           'am': 6012,
#           'est': 271,
#           'until': 557,
#           'pm': 1082,
#           'activity': 276,
#           'required': 2647,
#           'test': 1816,
#           'all': 6791,
#           'circuit': 55,
#           'breakers': 3,
#           'main': 337,
#           'circuits': 26,
#           'as': 14027,
#           'well': 980,
#           'connections': 202,
#           'electrical': 48,
#           'post': 281,
#           'where': 912,
#           'business': 1955,
#           'will': 9157,
#           'be': 19730,
#           'risk': 240,
#           'executed': 53,
#           'above': 480,
#           'outage': 69,
#           'approve': 359,
#           'impact': 126,
#           'manufacturing': 408,
#           'process': 1669,
#           'due': 1465,
#           'holiday': 131,
#           'schedules': 76,
#           'local': 3191,
#           'turn': 306,
#           'off': 930,
#           'unplugged': 29,
#           'mxtij': 51,
#           'switches': 179,
#           'servers': 1504,
#           'security': 1316,
#           'door': 96,
#           'system': 4172,
#           'during': 861,
#           'period': 326,
#           'time': 2818,
#           're': 1686,
#           'extension': 2157,
#           'voice': 525,
#           'mail': 2876,
#           'user': 7620,
#           'name': 6121,
#           'juan': 117,
#           'quintero': 10,
#           'aldo': 27,
#           'castro': 44,
#           'add': 8592,
#           'license': 2094,
#           'microsoft': 2221,
#           'teams': 596,
#           'ticket': 5112,
#           'itam': 254,
#           'sam': 361,
#           'manager': 3067,
#           'queue': 963,
#           'sap': 8050,
#           'document': 879,
#           'release': 431,
#           'doc': 183,
#           'acct': 131,
#           'showing': 618,
#           'an': 8316,
#           'error': 2648,
#           'needs': 6508,
#           'create': 4485,
#           'accounting': 249,
#           'so': 5782,
#           'can': 13686,
#           'cleared': 47,
#           'sitting': 139,
#           'in': 39181,
#           'pr': 361,
#           'ellen': 40,
#           'walden': 11,
#           'battery': 572,
#           'laptop': 9454,
#           'model': 683,
#           'precision': 263,
#           'ca': 2024,
#           "n't": 3320,
#           'my': 19975,
#           'h': 525,
#           'drive': 4252,
#           'forward': 1930,
#           'derek': 129,
#           'hantz': 36,
#           'or': 5838,
#           'todd': 80,
#           'heslor': 32,
#           'they': 2479,
#           'fix': 589,
#           'via': 1090,
#           'skype': 811,
#           'thanks': 6567,
#           'minidisplay': 2,
#           'port': 1646,
#           'hello': 2462,
#           'adapter': 219,
#           'hdmi': 103,
#           'regards': 2295,
#           'ivan': 38,
#           'discuss': 78,
#           'how': 1252,
#           'move': 2231,
#           'moving': 576,
#           'legacy': 314,
#           'iconnect': 877,
#           'utilizing': 36,
#           'sql': 1103,
#           'should': 2906,
#           'likely': 76,
#           'go': 850,
#           'bk': 42,
#           'manjunath': 9,
#           'manunath': 1,
#           'karthikeyan': 5,
#           'krishna': 31,
#           'met': 47,
#           'me': 7634,
#           'april': 507,
#           'we': 12976,
#           'reviewed': 76,
#           'particular': 79,
#           'basically': 32,
#           'what': 1236,
#           'collaborate': 39,
#           'get': 3756,
#           'background': 165,
#           'built': 81,
#           'build': 284,
#           'front': 153,
#           'app': 567,
#           'believe': 312,
#           'plan': 403,
#           'replicate': 54,
#           'existing': 1153,
#           'sharepoint': 1176,
#           'list': 4953,
#           'tables': 220,
#           's': 1331,
#           'help': 3997,
#           'understand': 197,
#           'difference': 46,
#           'working': 3497,
#           'table': 873,
#           'versus': 10,
#           'point': 717,
#           'helpful': 66,
#           'resource': 372,
#           'ensure': 623,
#           'using': 1875,
#           'function': 461,
#           'out': 3300,
#           'box': 1116,
#           'which': 2811,
#           'very': 876,
#           'similar': 410,
#           'now': 2423,
#           'here': 794,
#           'link': 1176,
#           'then': 1006,
#           'once': 601,
#           'that': 13250,
#           'done': 743,
#           "'ll": 170,
#           'someone': 665,
#           'support': 5647,
#           'needed': 2554,
#           'try': 639,
#           'their': 1221,
#           'apps': 256,
#           'form': 1204,
#           'provide': 4048,
#           'some': 1870,
#           'requested': 1144,
#           'functionality': 244,
#           'able': 3450,
#           'do': 5081,
#           'most': 312,
#           'portion': 41,
#           'myself': 532,
#           'but': 5455,
#           'would': 7242,
#           'guidance': 58,
#           'relates': 15,
#           'interfacing': 2,
#           'instead': 457,
#           'one': 3788,
#           'thing': 57,
#           'different': 642,
#           'are': 9099,
#           'each': 841,
#           'customer': 3054,
#           'solution': 281,
#           'use': 4079,
#           'same': 2178,
#           'customers': 794,
#           'assing': 103,
#           'latam': 830,
#           'e': 4402,
#           'mdm': 913,
#           'por': 627,
#           'favor': 770,
#           'desbloquear': 66,
#           'os': 464,
#           'fornecedores': 10,
#           'para': 967,
#           'pagamento': 24,
#           'de': 2625,
#           'concur': 257,
#           'monica': 181,
#           'purita': 3,
#           'wde': 72,
#           'pls': 280,
#           'profile': 666,
#           'care': 258,
#           'member': 521,
#           'june': 502,
#           'copy': 924,
#           'exactly': 58,
#           'michela': 4,
#           'cannizzo': 1,
#           'view': 841,
#           'search': 334,
#           'funtion': 7,
#           'properly': 538,
#           'outlook': 3765,
#           'no': 4836,
#           'longer': 1687,
#           'through': 1370,
#           'mailbox': 1660,
#           'folders': 1022,
#           'intern': 212,
#           'larry': 104,
#           'newman': 5,
#           'summer': 62,
#           'creating': 334,
#           'page': 883,
#           'asset': 293,
#           'management': 811,
#           'people': 951,
#           'report': 5341,
#           'ideas': 16,
#           'cost': 810,
#           'avoidance': 2,
#           'energy': 17,
#           'savings': 31,
#           'project': 3170,
#           'gaps': 3,
#           'however': 867,
#           'constructing': 1,
#           'hyperlinks': 3,
#           'drop': 311,
#           'down': 860,
#           'menus': 34,
#           'accessible': 143,
#           'life': 367,
#           'wanted': 142,
#           'assistance': 853,
#           'instructions': 296,
#           'phone': 7885,
#           'numbers': 671,
#           'show': 529,
#           'up': 8307,
#           'work': 4454,
#           'cell': 655,
#           'thank': 5757,
#           'you': 14875,
#           'much': 424,
#           'erik': 62,
#           'terminated': 532,
#           'employee': 3030,
#           'tatyana': 1,
#           'thalhofer': 1,
#           'may': 1544,
#           'several': 610,
#           'personal': 455,
#           'trips': 14,
#           'coming': 346,
#           'backup': 1115,
#           'her': 3209,
#           'like': 6193,
#           'these': 2842,
#           'archived': 108,
#           'travel': 230,
#           'st': 216,
#           'petersburg': 1,
#           'denver': 10,
#           'hi': 4206,
#           'lpg': 430,
#           'lcd': 620,
#           'tj': 349,
#           'group': 7309,
#           'setup': 2546,
#           'windows': 2446,
#           'macola': 913,
#           'wms': 316,
#           'maria': 187,
#           'del': 710,
#           'carmen': 45,
#           'valenzuela': 7,
#           'attach': 320,
#           'steven': 373,
#           'leng': 196,
#           'singapore': 278,
#           'sure': 750,
#           'wrong': 334,
#           'order': 5419,
#           'flagging': 2,
#           'buyers': 30,
#           'issue': 2505,
#           'intercompany': 134,
#           'po': 805,
#           'contacted': 194,
#           'computer': 7508,
#           'pickup': 53,
#           'santa': 160,
#           'clars': 1,
#           'fs': 410,
#           'clara': 153,
#           'location': 2207,
#           'computers': 861,
#           'reclaimed': 5,
#           'office': 7227,
#           'rm': 196,
#           'bldg': 302,
#           'final': 167,
#           'reminder': 32,
#           'thermo': 2584,
#           'global': 1573,
#           'instance': 392,
#           'series': 159,
#           'refresh': 330,
#           'planned': 117,
#           'non': 551,
#           'production': 1645,
#           'systems': 744,
#           'refreshed': 67,
#           'ecc': 71,
#           'crm': 312,
#           'bi': 664,
#           'scm': 50,
#           'ewm': 27,
#           'instances': 129,
#           'unavailable': 90,
#           'let': 1712,
#           'basis': 583,
#           'know': 2311,
#           'questions': 1092,
#           'reached': 110,
#           'ejm': 12787,
#           'eto': 849,
#           'current': 2418,
#           'upgraded': 632,
#           'xtp': 11,
#           'big': 130,
#           'data': 4539,
#           'migrate': 196,
#           'website': 445,
#           'server': 5524,
#           'called': 588,
#           'ussjo': 96,
#           'ws': 32,
#           'reguirements': 1,
#           'ram': 471,
#           'latest': 395,
#           'storage': 833,
#           'c': 2009,
#           'd': 4386,
#           'gb': 767,
#           'database': 1519,
#           'db': 680,
#           'requirements': 356,
#           'increases': 6,
#           'san': 551,
#           'jose': 295,
#           'update': 4394,
#           'infrastructure': 171,
#           'cartridge': 156,
#           'printer': 4425,
#           'dell': 1009,
#           'receive': 989,
#           'message': 1977,
#           'almost': 89,
#           'empty': 159,
#           'possible': 1750,
#           'take': 800,
#           'breda': 59,
#           'friday': 673,
#           'keeps': 234,
#           'losing': 27,
#           'connection': 1304,
#           'really': 174,
#           'slow': 574,
#           'open': 2192,
#           'applications': 885,
#           'owners': 86,
#           'contact': 2460,
#           'them': 1455,
#           'chromeleon': 136,
#           'machines': 343,
#           'exist': 171,
#           'safely': 13,
#           'remove': 2927,
#           'domain': 1193,
#           'registered': 77,
#           'require': 1970,
#           'labels': 372,
#           'aqualine': 4,
#           'water': 27,
#           'std': 75,
#           'mg': 37,
#           'ml': 35,
#           'k': 488,
#           'batch': 552,
#           'bottle': 31,
#           'transport': 158,
#           'l': 602,
#           'bottles': 15,
#           'monday': 824,
#           'tuesday': 286,
#           'next': 937,
#           'week': 1082,
#           'ship': 614,
#           'material': 1191,
#           'packing': 154,
#           'kevin': 460,
#           'ballard': 135,
#           'prints': 73,
#           'could': 3339,
#           'he': 2789,
#           'give': 1479,
#           'either': 365,
#           'mark': 560,
#           'bonam': 2,
#           'amy': 180,
#           'woodward': 18,
#           'svs': 6,
#           'acceso': 319,
#           'carpeta': 56,
#           'pueden': 13,
#           'ayudar': 18,
#           'dando': 3,
#           'la': 627,
#           'n': 1099,
#           'public': 611,
#           'moldeo': 50,
#           'racas': 11,
#           'al': 288,
#           'usuario': 212,
#           'kathy': 109,
#           'arrange': 197,
#           'scanner': 472,
#           'address': 3686,
#           'book': 556,
#           'first': 670,
#           'loaner': 592,
#           "'m": 1243,
#           'currently': 2774,
#           'active': 1537,
#           'opened': 442,
#           'around': 232,
#           "'ve": 508,
#           'instructed': 58,
#           'place': 1050,
#           'general': 1926,
#           'inorder': 4,
#           'delivered': 178,
#           'read': 1596,
#           'write': 977,
#           'multiple': 515,
#           'drives': 413,
#           'lead': 256,
#           'htp': 23,
#           'files': 2487,
#           'usple': 19,
#           'g': 1100,
#           'zytz': 2,
#           'p': 1424,
#           'qc': 516,
#           'q': 512,
#           'xpo': 41,
#           'forms': 351,
#           'x': 1168,
#           'more': 1437,
#           'information': 2776,
#           'atlin': 39,
#           'mailboxes': 202,
#           'nt': 380,
#           'connect': 1956,
#           'linz': 277,
#           'desktop': 1888,
#           'application': 2298,
#           'reported': 140,
#           'users': 2481,
#           'bilandzija': 2,
#           'mateo': 3,
#           'reinhard': 7,
#           'fitzinger': 4,
#           'roland': 18,
#           'horky': 3,
#           'thorsten': 8,
#           'aistleitner': 5,
#           'david': 708,
#           'stellenberger': 1,
#           'thermofisher': 669,
#           'com': 478,
#           'installation': 2091,
#           'notepad': 12,
#           'smmsmicha': 1,
#           'smms': 1,
#           'installer': 56,
#           'already': 1666,
#           'downloaded': 158,
#           'defaulting': 9,
#           'plant': 924,
#           'defaulted': 11,
#           'when': 4741,
#           'monterrey': 16,
#           'item': 1214,
#           'shipping': 535,
#           'dallas': 17,
#           'checked': 260,
#           'cmir': 1,
#           'listed': 595,
#           'default': 414,
#           'went': 156,
#           'past': 316,
#           'caused': 70,
#           'cas': 127,
#           'detractor': 1,
#           'hk': 15,
#           'incident': 193,
#           'entered': 243,
#           'purchase': 692,
#           'certificate': 399,
#           'official': 50,
#           'our': 4789,
#           'testrail': 16,
#           'enable': 929,
#           'ssl': 120,
#           'authority': 104,
#           'russel': 5,
#           'herbet': 2,
#           'russell': 49,
#           'company': 2259,
#           'contents': 92,
#           'his': 2971,
#           'pst': 218,
#           'file': 3586,
#           'mitch': 48,
#           'coyne': 10,
#           'former': 250,
#           'thru': 125,
#           'emails': 2444,
#           'related': 571,
#           'items': 827,
#           'lacking': 5,
#           'also': 3003,
#           'chris': 658,
#           'tate': 77,
#           'task': 1039,
#           'gui': 726,
#           'service': 4547,
#           'desk': 4424,
#           'follow': 424,
#           'below': 2698,
#           'kba': 83,
#           'complete': 1067,
#           'sapgui': 198,
#           'installing': 368,
#           'configuration': 670,
#           'sccm': 383,
#           'tamsyn': 5,
#           'lofts': 4,
#           'raise': 323,
#           'individuals': 143,
#           'distribution': 3284,
#           'lists': 598,
#           'ryan': 149,
#           'kaufman': 3,
#           'keith': 95,
#           'mcdaniel': 17,
#           'ljg': 2461,
#           'uslen': 46,
#           'cdcstocking': 1,
#           'static': 299,
#           'dns': 573,
#           'entries': 238,
#           'mentioned': 325,
#           'avaya': 2229,
#           'set': 5557,
#           'te': 65,
#           'line': 1479,
#           'gonzalez': 113,
#           'included': 255,
#           'cr': 264,
#           'side': 328,
#           'card': 721,
#           'dsn': 6,
#           'suffix': 11,
#           'vpn': 1226,
#           'image': 765,
#           'email': 9646,
#           'lsg': 2345,
#           'pleasanton': 223,
#           'planning': 348,
#           'making': 153,
#           'following': 4767,
#           'changes': 898,
#           'mitchell': 76,
#           'lee': 505,
#           'celina': 13,
#           'moulton': 4,
#           'ahmad': 24,
#           'bilal': 17,
#           'machine': 1008,
#           'created': 1729,
#           'ushil': 55,
#           'hbo': 45,
#           'seti': 9,
#           'owner': 921,
#           'permissions': 660,
#           'select': 233,
#           'checkbox': 8,
#           "'": 4073,
#           'membership': 140,
#           'critical': 245,
#           'check': 1570,
#           'without': 588,
#           'grant': 1407,
#           'netinfo': 20,
#           'members': 719,
#           'network': 4426,
#           'sandeep': 28,
#           'kontham': 2,
#           'brian': 321,
#           'muransky': 3,
#           'chidambaram': 2,
#           'adaikappan': 1,
#           'product': 1336,
#           'demos': 16,
#           'webex': 1998,
#           'two': 1702,
#           'hardwired': 15,
#           'only': 2526,
#           'across': 187,
#           'hall': 268,
#           'mine': 143,
#           'sales': 2575,
#           'ww': 8,
#           'sentinel': 2,
#           'tech': 394,
#           'learning': 609,
#           'gpms': 40,
#           'validation': 266,
#           'archive': 415,
#           'emea': 1423,
#           'shared': 2478,
#           'daily': 1252,
#           'addresses': 519,
#           'mailspace': 1,
#           'exceeded': 35,
#           'limit': 150,
#           'urgently': 189,
#           'older': 208,
#           'than': 642,
#           'subfolder': 27,
#           'inbox': 473,
#           'sent': 1796,
#           'save': 478,
#           'good': 438,
#           'automatic': 204,
#           'archiving': 64,
#           'rule': 182,
#           'manually': 260,
#           'best': 909,
#           'rebekka': 17,
#           'herzog': 5,
#           'automate': 61,
#           'removal': 189,
#           'discontinued': 32,
#           'products': 497,
#           'stock': 542,
#           'websmart': 3,
#           'publishing': 25,
#           'assignment': 1275,
#           'uswar': 401,
#           'published': 24,
#           'removed': 782,
#           'added': 2233,
#           'records': 496,
#           'old': 1987,
#           'web': 881,
#           'option': 617,
#           'odb': 52,
#           'menu': 296,
#           'addition': 307,
#           'outputs': 19,
#           'requires': 852,
#           'changing': 236,
#           'status': 1037,
#           'handled': 83,
#           'automatically': 416,
#           'just': 1174,
#           'got': 627,
#           'married': 119,
#           'changed': 1103,
#           'fournier': 2,
#           'previous': 617,
#           'gounon': 1,
#           'direct': 1048,
#           'delete': 996,
#           'field': 984,
#           'specialist': 323,
#           'after': 1708,
#           'say': 76,
#           'username': 513,
#           'example': 385,
#           'deactivate': 92,
#           'ad': 1521,
#           'shu': 21,
#           'chu': 24,
#           'chang': 41,
#           'amer': 1390,
#           'usfrd': 48,
#           'schang': 3,
#           'last': 1332,
#           'day': 1354,
#           'jmc': 5,
#           'executive': 101,
#           'way': 660,
#           'frederick': 188,
#           'md': 91,
#           'fisherbook': 46,
#           'dear': 813,
#           'contacts': 141,
#           'into': 3081,
#           'attached': 3896,
#           'your': 1951,
#           'reference': 513,
#           'veronica': 32,
#           'portillo': 9,
#           'licona': 1,
#           'raul': 9,
#           'gaytan': 5,
#           'kind': 468,
#           'credit': 368,
#           'transferred': 353,
#           'dvd': 143,
#           'player': 311,
#           'training': 1887,
#           'sessions': 130,
#           'merete': 7,
#           'miles': 43,
#           'approver': 139,
#           'ext': 529,
#           'anna': 69,
#           'kuok': 1,
#           'mails': 487,
#           'mohanan': 2,
#           'binu': 2,
#           'clarification': 34,
#           'reach': 279,
#           'mohammed': 21,
#           'imran': 11,
#           'kiosk': 71,
#           'area': 1317,
#           'salesforce': 197,
#           'newest': 83,
#           'version': 2620,
#           'admin': 1590,
#           'rights': 1055,
#           'upgrade': 2348,
#           'mobility': 26,
#           'headset': 1332,
#           'described': 23,
#           'apd': 184,
#           'becoming': 40,
#           'large': 352,
#           'send': 1703,
#           'maximo': 566,
#           'meg': 214,
#           'run': 1874,
#           'billable': 187,
#           'pending': 362,
#           'hoc': 298,
#           'steph': 86,
#           'docuser': 20,
#           'posted': 90,
#           'event': 322,
#           'dm': 41,
#           'sysadmin': 15,
#           'ecmt': 4,
#           'description': 723,
#           'protocol': 303,
#           'tcp': 205,
#           'host': 505,
#           'dedicated': 160,
#           'dead': 57,
#           'letter': 57,
#           'thx': 107,
#           'obtain': 142,
#           'reset': 1335,
#           'passward': 1,
#           'jd': 64,
#           'edwards': 121,
#           'used': 2181,
#           'microarray': 44,
#           'lost': 460,
#           'password': 3027,
#           'login': 1520,
#           'nogaw': 1,
#           'amend': 98,
#           'gpm': 1350,
#           'those': 413,
#           'outlined': 9,
#           'charles': 106,
#           'role': 1119,
#           'jira': 478,
#           'requirement': 251,
#           'type': 917,
#           'fblt': 3,
#           'termination': 332,
#           'jesus': 70,
#           'varela': 5,
#           'date': 2011,
#           'apr': 82,
#           'reserved': 78,
#           'must': 525,
#           'cancel': 243,
#           'enter': 574,
#           'colocarle': 9,
#           'sku': 581,
#           'unidad': 6,
#           'medida': 4,
#           'renew': 70,
#           'sign': 395,
#           'orders': 1503,
#           'connecting': 333,
#           'tiffany': 41,
#           'restarted': 72,
#           'still': 1128,
#           'directory': 1366,
#           'gateway': 267,
#           'follows': 340,
#           'step': 390,
#           'bsd': 152,
#           'fcs': 637,
#           'gatewayusers': 51,
#           'completed': 730,
#           'before': 973,
#           'performed': 272,
#           'attributes': 82,
#           'emp': 83,
#           'cspm': 52,
#           'muzio': 2,
#           'julie': 132,
#           'allentown': 543,
#           'pa': 199,
#           'andrew': 258,
#           'lms': 262,
#           'assist': 704,
#           'getting': 889,
#           'servicenow': 194,
#           'canada': 295,
#           'ottawa': 27,
#           'canep': 59,
#           'mainframe': 465,
#           'deskside': 245,
#           'automation': 189,
#           'font': 133,
#           'installed': 3491,
#           'scan': 402,
#           'sheets': 76,
#           'kanban': 62,
#           'cards': 82,
#           'usash': 301,
#           'mnbv': 2,
#           'hardware': 505,
#           'look': 579,
#           't': 851,
#           'flex': 40,
#           'usb': 340,
#           'devices': 244,
#           'pulling': 85,
#           'better': 275,
#           ...}),
#  'itos': ['<unk>',
#   '<pad>',
#   '<sos>',
#   '<eos>',
#   'to',
#   'the',
#   'njm',
#   'for',
#   'i',
#   'and',
#   'ajn',
#   'please',
#   'in',
#   'a',
#   'is',
#   'need',
#   'access',
#   'on',
#   'of',
#   'this',
#   'my',
#   'be',
#   'it',
#   'have',
#   'new',
#   'not',
#   'from',
#   'you',
#   'as',
#   'with',
#   'can',
#   'that',
#   'we',
#   'ejm',
#   'request',
#   'email',
#   'laptop',
#   'will',
#   'are',
#   'add',
#   'team',
#   'an',
#   'up',
#   'sap',
#   'phone',
#   'ljk',
#   'me',
#   'user',
#   'computer',
#   'group',
#   'has',
#   'would',
#   'office',
#   'account',
#   'all',
#   'at',
#   'thanks',
#   'needs',
#   "'s",
#   'like',
#   'assign',
#   'name',
#   'am',
#   'or',
#   'so',
#   'thank',
#   'support',
#   'set',
#   'server',
#   'but',
#   'order',
#   'report',
#   'if',
#   'was',
#   'change',
#   'ticket',
#   'do',
#   'by',
#   'list',
#   'site',
#   'no',
#   'install',
#   'our',
#   'following',
#   'when',
#   'software',
#   'service',
#   'data',
#   'create',
#   'work',
#   'network',
#   'printer',
#   'desk',
#   'e',
#   'update',
#   'd',
#   'number',
#   'drive',
#   'hi',
#   'system',
#   'use',
#   "'",
#   'provide',
#   'help',
#   'attached',
#   'been',
#   'one',
#   'outlook',
#   'get',
#   'address',
#   'folder',
#   'file',
#   'working',
#   'installed',
#   'able',
#   'pc',
#   'any',
#   '&',
#   'could',
#   "n't",
#   'out',
#   'distribution',
#   'room',
#   'her',
#   'local',
#   'project',
#   'there',
#   'into',
#   'manager',
#   'customer',
#   'employee',
#   'password',
#   'also',
#   'his',
#   'remove',
#   'should',
#   'see',
#   'mail',
#   'these',
#   'time',
#   'which',
#   'he',
#   'information',
#   'currently',
#   'below',
#   'error',
#   'required',
#   'de',
#   'version',
#   'thermo',
#   'sales',
#   'needed',
#   'setup',
#   'only',
#   'issue',
#   'code',
#   'files',
#   'users',
#   'they',
#   'shared',
#   'hello',
#   'ljg',
#   'contact',
#   'windows',
#   'fisher',
#   'emails',
#   'now',
#   'current',
#   'part',
#   'requesting',
#   'upgrade',
#   'does',
#   'lsg',
#   'know',
#   'application',
#   'regards',
#   'us',
#   'company',
#   'added',
#   'move',
#   'she',
#   'avaya',
#   'microsoft',
#   'location',
#   'open',
#   'used',
#   'same',
#   'extension',
#   'license',
#   'installation',
#   'ca',
#   'date',
#   'ip',
#   'c',
#   'webex',
#   'old',
#   'message',
#   'require',
#   'connect',
#   'business',
#   'your',
#   'forward',
#   'general',
#   'hire',
#   'desktop',
#   'training',
#   'other',
#   'using',
#   'run',
#   'some',
#   'test',
#   'genesys',
#   'sent',
#   'gis',
#   'center',
#   'possible',
#   'created',
#   'excel',
#   'log',
#   'let',
#   'job',
#   'after',
#   'meeting',
#   'send',
#   'two',
#   'reports',
#   'longer',
#   're',
#   'unable',
#   'process',
#   'monitor',
#   'already',
#   'mailbox',
#   'port',
#   'production',
#   'make',
#   'read',
#   'admin',
#   'call',
#   'received',
#   'global',
#   'check',
#   'may',
#   'back',
#   'active',
#   'conference',
#   'ad',
#   'login',
#   'database',
#   'servers',
#   'orders',
#   'who',
#   'give',
#   'line',
#   'due',
#   'station',
#   'them',
#   'issues',
#   'details',
#   'services',
#   'pro',
#   'more',
#   'p',
#   'emea',
#   'grant',
#   'lab',
#   'amer',
#   'screen',
#   'through',
#   'available',
#   'directory',
#   'per',
#   'day',
#   'gpm',
#   'product',
#   'reset',
#   'space',
#   'headset',
#   'last',
#   'want',
#   's',
#   'approval',
#   'area',
#   'security',
#   'updated',
#   'connection',
#   'being',
#   'had',
#   'print',
#   'assignment',
#   'program',
#   'because',
#   'm',
#   'route',
#   'daily',
#   'how',
#   'additional',
#   "'m",
#   'documents',
#   'client',
#   'what',
#   'vpn',
#   'their',
#   'under',
#   'item',
#   'transfer',
#   'form',
#   'ms',
#   'domain',
#   'material',
#   'mobile',
#   'since',
#   'find',
#   'link',
#   'sharepoint',
#   'assigned',
#   'just',
#   'start',
#   'x',
#   'full',
#   'agent',
#   'existing',
#   'moved',
#   'requested',
#   'wireless',
#   'still',
#   'role',
#   'box',
#   'hr',
#   'backup',
#   'changed',
#   'sql',
#   'g',
#   'n',
#   'questions',
#   'located',
#   'via',
#   'remote',
#   'pm',
#   'week',
#   'calls',
#   'complete',
#   'over',
#   'employees',
#   'allow',
#   'accounts',
#   'rights',
#   'internet',
#   'docking',
#   'place',
#   'direct',
#   'task',
#   'status',
#   'both',
#   'folders',
#   'end',
#   'scientific',
#   'share',
#   'dell',
#   'machine',
#   'then',
#   'delete',
#   'power',
#   'groups',
#   'receive',
#   'field',
#   'well',
#   'write',
#   'before',
#   'trying',
#   'para',
#   'equipment',
#   'queue',
#   'having',
#   'people',
#   'portal',
#   'wifi',
#   'department',
#   'calendar',
#   'next',
#   'creation',
#   'advance',
#   'off',
#   'enable',
#   'building',
#   'copy',
#   'plant',
#   'b',
#   'owner',
#   'pdf',
#   'type',
#   'control',
#   'macola',
#   'mdm',
#   'home',
#   'where',
#   'did',
#   'many',
#   'best',
#   'running',
#   'changes',
#   'engineering',
#   'o',
#   'getting',
#   'left',
#   'applications',
#   'page',
#   'web',
#   'document',
#   'iconnect',
#   'very',
#   'table',
#   'etc',
#   'djt',
#   'however',
#   'upload',
#   'computers',
#   'during',
#   'were',
#   'down',
#   'telephone',
#   'invoice',
#   'monitors',
#   'today',
#   'assistance',
#   'na',
#   'requires',
#   't',
#   'go',
#   'correct',
#   'eto',
#   'within',
#   'each',
#   'view',
#   'extend',
#   'tool',
#   'storage',
#   'aws',
#   'latam',
#   'vendor',
#   'starting',
#   'items',
#   'ports',
#   'problem',
#   'monday',
#   'finance',
#   'monitoring',
#   'uk',
#   'replace',
#   'urgent',
#   'dear',
#   'management',
#   'replacement',
#   'skype',
#   'cost',
#   'adobe',
#   'po',
#   'load',
#   'take',
#   'another',
#   'customers',
#   'here',
#   'qad',
#   'recently',
#   'switch',
#   'asap',
#   'removed',
#   'ipad',
#   'lot',
#   'qa',
#   'connected',
#   'favor',
#   'note',
#   'gb',
#   'label',
#   'image',
#   'john',
#   'about',
#   'floor',
#   'tried',
#   'prod',
#   'sure',
#   'printers',
#   'internal',
#   'systems',
#   'done',
#   'kindly',
#   'eas',
#   'master',
#   'carlsbad',
#   'completed',
#   'configure',
#   'soon',
#   'gui',
#   'inventory',
#   'put',
#   'description',
#   'card',
#   'members',
#   'while',
#   'him',
#   'perform',
#   'auto',
#   'point',
#   'receiving',
#   'laptops',
#   'attachment',
#   'del',
#   'include',
#   'david',
#   'baan',
#   'f',
#   'assist',
#   'testing',
#   'environment',
#   'operations',
#   'purchase',
#   'el',
#   'oracle',
#   'agile',
#   'ibs',
#   'michael',
#   'model',
#   'citrix',
#   'pjt',
#   'requests',
#   'administrator',
#   'db',
#   'standard',
#   'download',
#   'friday',
#   'numbers',
#   'case',
#   'configuration',
#   'first',
#   'thermofisher',
#   'profile',
#   'reporting',
#   'review',
#   'someone',
#   'bi',
#   'hard',
#   'permissions',
#   'way',
#   'chris',
#   'quality',
#   'notes',
#   'cell',
#   'ou',
#   'visio',
#   'r',
#   'keyboard',
#   'different',
#   'than',
#   'http',
#   'try',
#   'fcs',
#   'invoices',
#   'upgraded',
#   'forwarding',
#   'got',
#   'la',
#   'missing',
#   'por',
#   'looking',
#   'msd',
#   'cc',
#   'ensure',
#   'cognos',
#   'lcd',
#   'showing',
#   'option',
#   'previous',
#   'device',
#   'disk',
#   'ship',
#   'public',
#   'several',
#   'ccg',
#   'learning',
#   'warehouse',
#   'forwarded',
#   'rooms',
#   'priority',
#   'person',
#   'migration',
#   'en',
#   'l',
#   'workday',
#   'meetings',
#   'once',
#   'every',
#   'right',
#   'lists',
#   'query',
#   'teams',
#   'listed',
#   'loaner',
#   'activate',
#   'captiva',
#   'fix',
#   'called',
#   'plus',
#   'without',
#   'r&d',
#   'audit',
#   'level',
#   'basis',
#   'cube',
#   'days',
#   'key',
#   'sku',
#   'look',
#   'moving',
#   'enter',
#   'slow',
#   'v',
#   'dns',
#   'sites',
#   'battery',
#   'display',
#   'related',
#   'mouse',
#   'quote',
#   'template',
#   'setting',
#   'app',
#   'its',
#   'closed',
#   'maximo',
#   'specific',
#   'development',
#   'mark',
#   'permission',
#   'until',
#   'book',
#   'info',
#   'going',
#   'batch',
#   'leave',
#   'non',
#   'san',
#   'top',
#   'price',
#   'between',
#   'dev',
#   'allentown',
#   'based',
#   'stock',
#   'sdg',
#   'transaction',
#   'necessary',
#   'university',
#   "'d",
#   'colleague',
#   'properly',
#   'shipping',
#   'y',
#   'again',
#   'myself',
#   'terminated',
#   'workstation',
#   'mike',
#   'w',
#   'ext',
#   'show',
#   'h',
#   'must',
#   'voice',
#   'morning',
#   'cable',
#   'member',
#   'addresses',
#   'instrument',
#   'qc',
#   'external',
#   'multiple',
#   'reference',
#   'tools',
#   'username',
#   'q',
#   'uspgh',
#   'edit',
#   'schedule',
#   "'ve",
#   'approved',
#   'april',
#   'hardware',
#   'host',
#   'lee',
#   'provided',
#   'june',
#   'times',
#   'free',
#   'vm',
#   'month',
#   'products',
#   'unix',
#   'records',
#   'supervisor',
#   'close',
#   'dc',
#   'increase',
#   'k',
#   'apac',
#   'mails',
#   'projector',
#   'contractor',
#   'tfs',
#   'rsd',
#   'locked',
#   'names',
#   'above',
#   'subject',
#   'contract',
#   'com',
#   'jira',
#   'save',
#   'mac',
#   'works',
#   'flash',
#   'inbox',
#   'eu',
#   'scanner',
#   'ram',
#   'kind',
#   'says',
#   'mainframe',
#   'mbd',
#   'os',
#   'technical',
#   'function',
#   'july',
#   'restore',
#   'kevin',
#   'lost',
#   'memory',
#   'instead',
#   'year',
#   'found',
#   'iphone',
#   'printing',
#   'cloud',
#   'ethernet',
#   'personal',
#   'cs',
#   'j',
#   'onto',
#   'previously',
#   'maintenance',
#   'website',
#   'configured',
#   'keep',
#   'opened',
#   'cubicle',
#   'linux',
#   'cmd',
#   'second',
#   'good',
#   'asked',
#   'pop',
#   'analysis',
#   'voicemail',
#   'badge',
#   'made',
#   'release',
#   'lpg',
#   'patheon',
#   'few',
#   'hold',
#   'notification',
#   'record',
#   'updates',
#   'ask',
#   'em',
#   'deleted',
#   'entry',
#   'follow',
#   'much',
#   'format',
#   'package',
#   'effective',
#   'further',
#   'reason',
#   'automatically',
#   'hp',
#   'archive',
#   'delivery',
#   'content',
#   'default',
#   'gi',
#   'latitude',
#   'materials',
#   'drives',
#   'those',
#   'parts',
#   'submit',
#   'fs',
#   'purposes',
#   'similar',
#   'supply',
#   'william',
#   'corporate',
#   'delegate',
#   'manufacturing',
#   'regarding',
#   'india',
#   'supplier',
#   'given',
#   'plan',
#   'word',
#   'august',
#   'refer',
#   'scan',
#   'uswar',
#   'advise',
#   'certificate',
#   'pull',
#   'directly',
#   'shows',
#   'toner',
#   'settings',
#   'latest',
#   'sign',
#   'size',
#   'th',
#   'hand',
#   'tech',
#   'temp',
#   'ability',
#   'instance',
#   'return',
#   'marketing',
#   'video',
#   'weekly',
#   'core',
#   'step',
#   'temporary',
#   'codes',
#   'path',
#   'something',
#   'replaced',
#   'example',
#   'pittsburgh',
#   'se',
#   'disable',
#   'why',
#   'lines',
#   'sccm',
#   'asheville',
#   'hours',
#   'mr',
#   'nt',
#   'centrify',
#   'online',
#   'unit',
#   'fremont',
#   'such',
#   'modify',
#   'signature',
#   'cisco',
#   'clean',
#   'steven',
#   'catalog',
#   'fields',
#   'labels',
#   'lotus',
#   'resource',
#   'too',
#   'division',
#   'returned',
#   'phones',
#   'imaged',
#   'jan',
#   'jobs',
#   'credit',
#   'installing',
#   'low',
#   'life',
#   'bit',
#   'confirm',
#   'weeks',
#   'either',
#   'adding',
#   'spreadsheet',
#   'started',
#   'paul',
#   'generate',
#   'pending',
#   'pricing',
#   'pr',
#   'sam',
#   'approve',
#   'germany',
#   'session',
#   'therefore',
#   'programs',
#   'export',
#   'requirements',
#   'van',
#   'dl',
#   'seems',
#   'jde',
#   'siebel',
#   'transferred',
#   'large',
#   'reply',
#   'url',
#   'forms',
#   'long',
#   'purchasing',
#   'tj',
#   'mirror',
#   'planning',
#   'fixed',
#   'jim',
#   'coming',
#   'nitro',
#   'monthly',
#   'acs',
#   'ap',
#   'facility',
#   'mailto',
#   'projects',
#   'machines',
#   'follows',
#   'usb',
#   'scheduled',
#   'march',
#   'fax',
#   'high',
#   'inc',
#   'main',
#   'onedrive',
#   'roles',
#   'manage',
#   'vlan',
#   'come',
#   'pass',
#   'tag',
#   'creating',
#   'erp',
#   'search',
#   'wrong',
#   'click',
#   'connecting',
#   'versions',
#   'even',
#   'termination',
#   'acrobat',
#   'stage',
#   'que',
#   'refresh',
#   'activated',
#   'side',
#   'stop',
#   'u',
#   'martin',
#   'failed',
#   'period',
#   'tasks',
#   'mentioned',
#   'months',
#   'ops',
#   'processing',
#   'virtual',
#   'z',
#   'pre',
#   'raise',
#   'specialist',
#   'ago',
#   'diego',
#   'event',
#   'west',
#   'brian',
#   'ordered',
#   'thomas',
#   'attach',
#   'told',
#   'acceso',
#   'steve',
#   'including',
#   'objects',
#   'staff',
#   'pick',
#   'tax',
#   'three',
#   'workspace',
#   'anymore',
#   'past',
#   'recipient',
#   'wms',
#   'suite',
#   'legacy',
#   'bill',
#   'lan',
#   'logon',
#   'worker',
#   'believe',
#   'clinical',
#   ...],
#  'unk_index': 0,
#  'stoi': defaultdict(<bound method Vocab._default_unk_index of <torchtext.vocab.Vocab object at 0x171c2d350>>,
#              {'<unk>': 0,
#               '<pad>': 1,
#               '<sos>': 2,
#               '<eos>': 3,
#               'to': 4,
#               'the': 5,
#               'njm': 6,
#               'for': 7,
#               'i': 8,
#               'and': 9,
#               'ajn': 10,
#               'please': 11,
#               'in': 12,
#               'a': 13,
#               'is': 14,
#               'need': 15,
#               'access': 16,
#               'on': 17,
#               'of': 18,
#               'this': 19,
#               'my': 20,
#               'be': 21,
#               'it': 22,
#               'have': 23,
#               'new': 24,
#               'not': 25,
#               'from': 26,
#               'you': 27,
#               'as': 28,
#               'with': 29,
#               'can': 30,
#               'that': 31,
#               'we': 32,
#               'ejm': 33,
#               'request': 34,
#               'email': 35,
#               'laptop': 36,
#               'will': 37,
#               'are': 38,
#               'add': 39,
#               'team': 40,
#               'an': 41,
#               'up': 42,
#               'sap': 43,
#               'phone': 44,
#               'ljk': 45,
#               'me': 46,
#               'user': 47,
#               'computer': 48,
#               'group': 49,
#               'has': 50,
#               'would': 51,
#               'office': 52,
#               'account': 53,
#               'all': 54,
#               'at': 55,
#               'thanks': 56,
#               'needs': 57,
#               "'s": 58,
#               'like': 59,
#               'assign': 60,
#               'name': 61,
#               'am': 62,
#               'or': 63,
#               'so': 64,
#               'thank': 65,
#               'support': 66,
#               'set': 67,
#               'server': 68,
#               'but': 69,
#               'order': 70,
#               'report': 71,
#               'if': 72,
#               'was': 73,
#               'change': 74,
#               'ticket': 75,
#               'do': 76,
#               'by': 77,
#               'list': 78,
#               'site': 79,
#               'no': 80,
#               'install': 81,
#               'our': 82,
#               'following': 83,
#               'when': 84,
#               'software': 85,
#               'service': 86,
#               'data': 87,
#               'create': 88,
#               'work': 89,
#               'network': 90,
#               'printer': 91,
#               'desk': 92,
#               'e': 93,
#               'update': 94,
#               'd': 95,
#               'number': 96,
#               'drive': 97,
#               'hi': 98,
#               'system': 99,
#               'use': 100,
#               "'": 101,
#               'provide': 102,
#               'help': 103,
#               'attached': 104,
#               'been': 105,
#               'one': 106,
#               'outlook': 107,
#               'get': 108,
#               'address': 109,
#               'folder': 110,
#               'file': 111,
#               'working': 112,
#               'installed': 113,
#               'able': 114,
#               'pc': 115,
#               'any': 116,
#               '&': 117,
#               'could': 118,
#               "n't": 119,
#               'out': 120,
#               'distribution': 121,
#               'room': 122,
#               'her': 123,
#               'local': 124,
#               'project': 125,
#               'there': 126,
#               'into': 127,
#               'manager': 128,
#               'customer': 129,
#               'employee': 130,
#               'password': 131,
#               'also': 132,
#               'his': 133,
#               'remove': 134,
#               'should': 135,
#               'see': 136,
#               'mail': 137,
#               'these': 138,
#               'time': 139,
#               'which': 140,
#               'he': 141,
#               'information': 142,
#               'currently': 143,
#               'below': 144,
#               'error': 145,
#               'required': 146,
#               'de': 147,
#               'version': 148,
#               'thermo': 149,
#               'sales': 150,
#               'needed': 151,
#               'setup': 152,
#               'only': 153,
#               'issue': 154,
#               'code': 155,
#               'files': 156,
#               'users': 157,
#               'they': 158,
#               'shared': 159,
#               'hello': 160,
#               'ljg': 161,
#               'contact': 162,
#               'windows': 163,
#               'fisher': 164,
#               'emails': 165,
#               'now': 166,
#               'current': 167,
#               'part': 168,
#               'requesting': 169,
#               'upgrade': 170,
#               'does': 171,
#               'lsg': 172,
#               'know': 173,
#               'application': 174,
#               'regards': 175,
#               'us': 176,
#               'company': 177,
#               'added': 178,
#               'move': 179,
#               'she': 180,
#               'avaya': 181,
#               'microsoft': 182,
#               'location': 183,
#               'open': 184,
#               'used': 185,
#               'same': 186,
#               'extension': 187,
#               'license': 188,
#               'installation': 189,
#               'ca': 190,
#               'date': 191,
#               'ip': 192,
#               'c': 193,
#               'webex': 194,
#               'old': 195,
#               'message': 196,
#               'require': 197,
#               'connect': 198,
#               'business': 199,
#               'your': 200,
#               'forward': 201,
#               'general': 202,
#               'hire': 203,
#               'desktop': 204,
#               'training': 205,
#               'other': 206,
#               'using': 207,
#               'run': 208,
#               'some': 209,
#               'test': 210,
#               'genesys': 211,
#               'sent': 212,
#               'gis': 213,
#               'center': 214,
#               'possible': 215,
#               'created': 216,
#               'excel': 217,
#               'log': 218,
#               'let': 219,
#               'job': 220,
#               'after': 221,
#               'meeting': 222,
#               'send': 223,
#               'two': 224,
#               'reports': 225,
#               'longer': 226,
#               're': 227,
#               'unable': 228,
#               'process': 229,
#               'monitor': 230,
#               'already': 231,
#               'mailbox': 232,
#               'port': 233,
#               'production': 234,
#               'make': 235,
#               'read': 236,
#               'admin': 237,
#               'call': 238,
#               'received': 239,
#               'global': 240,
#               'check': 241,
#               'may': 242,
#               'back': 243,
#               'active': 244,
#               'conference': 245,
#               'ad': 246,
#               'login': 247,
#               'database': 248,
#               'servers': 249,
#               'orders': 250,
#               'who': 251,
#               'give': 252,
#               'line': 253,
#               'due': 254,
#               'station': 255,
#               'them': 256,
#               'issues': 257,
#               'details': 258,
#               'services': 259,
#               'pro': 260,
#               'more': 261,
#               'p': 262,
#               'emea': 263,
#               'grant': 264,
#               'lab': 265,
#               'amer': 266,
#               'screen': 267,
#               'through': 268,
#               'available': 269,
#               'directory': 270,
#               'per': 271,
#               'day': 272,
#               'gpm': 273,
#               'product': 274,
#               'reset': 275,
#               'space': 276,
#               'headset': 277,
#               'last': 278,
#               'want': 279,
#               's': 280,
#               'approval': 281,
#               'area': 282,
#               'security': 283,
#               'updated': 284,
#               'connection': 285,
#               'being': 286,
#               'had': 287,
#               'print': 288,
#               'assignment': 289,
#               'program': 290,
#               'because': 291,
#               'm': 292,
#               'route': 293,
#               'daily': 294,
#               'how': 295,
#               'additional': 296,
#               "'m": 297,
#               'documents': 298,
#               'client': 299,
#               'what': 300,
#               'vpn': 301,
#               'their': 302,
#               'under': 303,
#               'item': 304,
#               'transfer': 305,
#               'form': 306,
#               'ms': 307,
#               'domain': 308,
#               'material': 309,
#               'mobile': 310,
#               'since': 311,
#               'find': 312,
#               'link': 313,
#               'sharepoint': 314,
#               'assigned': 315,
#               'just': 316,
#               'start': 317,
#               'x': 318,
#               'full': 319,
#               'agent': 320,
#               'existing': 321,
#               'moved': 322,
#               'requested': 323,
#               'wireless': 324,
#               'still': 325,
#               'role': 326,
#               'box': 327,
#               'hr': 328,
#               'backup': 329,
#               'changed': 330,
#               'sql': 331,
#               'g': 332,
#               'n': 333,
#               'questions': 334,
#               'located': 335,
#               'via': 336,
#               'remote': 337,
#               'pm': 338,
#               'week': 339,
#               'calls': 340,
#               'complete': 341,
#               'over': 342,
#               'employees': 343,
#               'allow': 344,
#               'accounts': 345,
#               'rights': 346,
#               'internet': 347,
#               'docking': 348,
#               'place': 349,
#               'direct': 350,
#               'task': 351,
#               'status': 352,
#               'both': 353,
#               'folders': 354,
#               'end': 355,
#               'scientific': 356,
#               'share': 357,
#               'dell': 358,
#               'machine': 359,
#               'then': 360,
#               'delete': 361,
#               'power': 362,
#               'groups': 363,
#               'receive': 364,
#               'field': 365,
#               'well': 366,
#               'write': 367,
#               'before': 368,
#               'trying': 369,
#               'para': 370,
#               'equipment': 371,
#               'queue': 372,
#               'having': 373,
#               'people': 374,
#               'portal': 375,
#               'wifi': 376,
#               'department': 377,
#               'calendar': 378,
#               'next': 379,
#               'creation': 380,
#               'advance': 381,
#               'off': 382,
#               'enable': 383,
#               'building': 384,
#               'copy': 385,
#               'plant': 386,
#               'b': 387,
#               'owner': 388,
#               'pdf': 389,
#               'type': 390,
#               'control': 391,
#               'macola': 392,
#               'mdm': 393,
#               'home': 394,
#               'where': 395,
#               'did': 396,
#               'many': 397,
#               'best': 398,
#               'running': 399,
#               'changes': 400,
#               'engineering': 401,
#               'o': 402,
#               'getting': 403,
#               'left': 404,
#               'applications': 405,
#               'page': 406,
#               'web': 407,
#               'document': 408,
#               'iconnect': 409,
#               'very': 410,
#               'table': 411,
#               'etc': 412,
#               'djt': 413,
#               'however': 414,
#               'upload': 415,
#               'computers': 416,
#               'during': 417,
#               'were': 418,
#               'down': 419,
# ...
#               'monday': 444,
#               'finance': 445,
#               'monitoring': 446,
#               'uk': 447,
#               'replace': 448,
#               'urgent': 449,
#               'dear': 450,
#               'management': 451,
#               'replacement': 452,
#               'skype': 453,
#               'cost': 454,
#               'adobe': 455,
#               'po': 456,
#               'load': 457,
#               'take': 458,
#               'another': 459,
#               'customers': 460,
#               'here': 461,
#               'qad': 462,
#               'recently': 463,
#               'switch': 464,
#               'asap': 465,
#               'removed': 466,
#               'ipad': 467,
#               'lot': 468,
#               'qa': 469,
#               'connected': 470,
#               'favor': 471,
#               'note': 472,
#               'gb': 473,
#               'label': 474,
#               'image': 475,
#               'john': 476,
#               'about': 477,
#               'floor': 478,
#               'tried': 479,
#               'prod': 480,
#               'sure': 481,
#               'printers': 482,
#               'internal': 483,
#               'systems': 484,
#               'done': 485,
#               'kindly': 486,
#               'eas': 487,
#               'master': 488,
#               'carlsbad': 489,
#               'completed': 490,
#               'configure': 491,
#               'soon': 492,
#               'gui': 493,
#               'inventory': 494,
#               'put': 495,
#               'description': 496,
#               'card': 497,
#               'members': 498,
#               'while': 499,
#               'him': 500,
#               'perform': 501,
#               'auto': 502,
#               'point': 503,
#               'receiving': 504,
#               'laptops': 505,
#               'attachment': 506,
#               'del': 507,
#               'include': 508,
#               'david': 509,
#               'baan': 510,
#               'f': 511,
#               'assist': 512,
#               'testing': 513,
#               'environment': 514,
#               'operations': 515,
#               'purchase': 516,
#               'el': 517,
#               'oracle': 518,
#               'agile': 519,
#               'ibs': 520,
#               'michael': 521,
#               'model': 522,
#               'citrix': 523,
#               'pjt': 524,
#               'requests': 525,
#               'administrator': 526,
#               'db': 527,
#               'standard': 528,
#               'download': 529,
#               'friday': 530,
#               'numbers': 531,
#               'case': 532,
#               'configuration': 533,
#               'first': 534,
#               'thermofisher': 535,
#               'profile': 536,
#               'reporting': 537,
#               'review': 538,
#               'someone': 539,
#               'bi': 540,
#               'hard': 541,
#               'permissions': 542,
#               'way': 543,
#               'chris': 544,
#               'quality': 545,
#               'notes': 546,
#               'cell': 547,
#               'ou': 548,
#               'visio': 549,
#               'r': 550,
#               'keyboard': 551,
#               'different': 552,
#               'than': 553,
#               'http': 554,
#               'try': 555,
#               'fcs': 556,
#               'invoices': 557,
#               'upgraded': 558,
#               'forwarding': 559,
#               'got': 560,
#               'la': 561,
#               'missing': 562,
#               'por': 563,
#               'looking': 564,
#               'msd': 565,
#               'cc': 566,
#               'ensure': 567,
#               'cognos': 568,
#               'lcd': 569,
#               'showing': 570,
#               'option': 571,
#               'previous': 572,
#               'device': 573,
#               'disk': 574,
#               'ship': 575,
#               'public': 576,
#               'several': 577,
#               'ccg': 578,
#               'learning': 579,
#               'warehouse': 580,
#               'forwarded': 581,
#               'rooms': 582,
#               'priority': 583,
#               'person': 584,
#               'migration': 585,
#               'en': 586,
#               'l': 587,
#               'workday': 588,
#               'meetings': 589,
#               'once': 590,
#               'every': 591,
#               'right': 592,
#               'lists': 593,
#               'query': 594,
#               'teams': 595,
#               'listed': 596,
#               'loaner': 597,
#               'activate': 598,
#               'captiva': 599,
#               'fix': 600,
#               'called': 601,
#               'plus': 602,
#               'without': 603,
#               'r&d': 604,
#               'audit': 605,
#               'level': 606,
#               'basis': 607,
#               'cube': 608,
#               'days': 609,
#               'key': 610,
#               'sku': 611,
#               'look': 612,
#               'moving': 613,
#               'enter': 614,
#               'slow': 615,
#               'v': 616,
#               'dns': 617,
#               'sites': 618,
#               'battery': 619,
#               'display': 620,
#               'related': 621,
#               'mouse': 622,
#               'quote': 623,
#               'template': 624,
#               'setting': 625,
#               'app': 626,
#               'its': 627,
#               'closed': 628,
#               'maximo': 629,
#               'specific': 630,
#               'development': 631,
#               'mark': 632,
#               'permission': 633,
#               'until': 634,
#               'book': 635,
#               'info': 636,
#               'going': 637,
#               'batch': 638,
#               'leave': 639,
#               'non': 640,
#               'san': 641,
#               'top': 642,
#               'price': 643,
#               'between': 644,
#               'dev': 645,
#               'allentown': 646,
#               'based': 647,
#               'stock': 648,
#               'sdg': 649,
#               'transaction': 650,
#               'necessary': 651,
#               'university': 652,
#               "'d": 653,
#               'colleague': 654,
#               'properly': 655,
#               'shipping': 656,
#               'y': 657,
#               'again': 658,
#               'myself': 659,
#               'terminated': 660,
#               'workstation': 661,
#               'mike': 662,
#               'w': 663,
#               'ext': 664,
#               'show': 665,
#               'h': 666,
#               'must': 667,
#               'voice': 668,
#               'morning': 669,
#               'cable': 670,
#               'member': 671,
#               'addresses': 672,
#               'instrument': 673,
#               'qc': 674,
#               'external': 675,
#               'multiple': 676,
#               'reference': 677,
#               'tools': 678,
#               'username': 679,
#               'q': 680,
#               'uspgh': 681,
#               'edit': 682,
#               'schedule': 683,
#               "'ve": 684,
#               'approved': 685,
#               'april': 686,
#               'hardware': 687,
#               'host': 688,
#               'lee': 689,
#               'provided': 690,
#               'june': 691,
#               'times': 692,
#               'free': 693,
#               'vm': 694,
#               'month': 695,
#               'products': 696,
#               'unix': 697,
#               'records': 698,
#               'supervisor': 699,
#               'close': 700,
#               'dc': 701,
#               'increase': 702,
#               'k': 703,
#               'apac': 704,
#               'mails': 705,
#               'projector': 706,
#               'contractor': 707,
#               'tfs': 708,
#               'rsd': 709,
#               'locked': 710,
#               'names': 711,
#               'above': 712,
#               'subject': 713,
#               'contract': 714,
#               'com': 715,
#               'jira': 716,
#               'save': 717,
#               'mac': 718,
#               'works': 719,
#               'flash': 720,
#               'inbox': 721,
#               'eu': 722,
#               'scanner': 723,
#               'ram': 724,
#               'kind': 725,
#               'says': 726,
#               'mainframe': 727,
#               'mbd': 728,
#               'os': 729,
#               'technical': 730,
#               'function': 731,
#               'july': 732,
#               'restore': 733,
#               'kevin': 734,
#               'lost': 735,
#               'memory': 736,
#               'instead': 737,
#               'year': 738,
#               'found': 739,
#               'iphone': 740,
#               'printing': 741,
#               'cloud': 742,
#               'ethernet': 743,
#               'personal': 744,
#               'cs': 745,
#               'j': 746,
#               'onto': 747,
#               'previously': 748,
#               'maintenance': 749,
#               'website': 750,
#               'configured': 751,
#               'keep': 752,
#               'opened': 753,
#               'cubicle': 754,
#               'linux': 755,
#               'cmd': 756,
#               'second': 757,
#               'good': 758,
#               'asked': 759,
#               'pop': 760,
#               'analysis': 761,
#               'voicemail': 762,
#               'badge': 763,
#               'made': 764,
#               'release': 765,
#               'lpg': 766,
#               'patheon': 767,
#               'few': 768,
#               'hold': 769,
#               'notification': 770,
#               'record': 771,
#               'updates': 772,
#               'ask': 773,
#               'em': 774,
#               'deleted': 775,
#               'entry': 776,
#               'follow': 777,
#               'much': 778,
#               'format': 779,
#               'package': 780,
#               'effective': 781,
#               'further': 782,
#               'reason': 783,
#               'automatically': 784,
#               'hp': 785,
#               'archive': 786,
#               'delivery': 787,
#               'content': 788,
#               'default': 789,
#               'gi': 790,
#               'latitude': 791,
#               'materials': 792,
#               'drives': 793,
#               'those': 794,
#               'parts': 795,
#               'submit': 796,
#               'fs': 797,
#               'purposes': 798,
#               'similar': 799,
#               'supply': 800,
#               'william': 801,
#               'corporate': 802,
#               'delegate': 803,
#               'manufacturing': 804,
#               'regarding': 805,
#               'india': 806,
#               'supplier': 807,
#               'given': 808,
#               'plan': 809,
#               'word': 810,
#               'august': 811,
#               'refer': 812,
#               'scan': 813,
#               'uswar': 814,
#               'advise': 815,
#               'certificate': 816,
#               'pull': 817,
#               'directly': 818,
#               'shows': 819,
#               'toner': 820,
#               'settings': 821,
#               'latest': 822,
#               'sign': 823,
#               'size': 824,
#               'th': 825,
#               'hand': 826,
#               'tech': 827,
#               'temp': 828,
#               'ability': 829,
#               'instance': 830,
#               'return': 831,
#               'marketing': 832,
#               'video': 833,
#               'weekly': 834,
#               'core': 835,
#               'step': 836,
#               'temporary': 837,
#               'codes': 838,
#               'path': 839,
#               'something': 840,
#               'replaced': 841,
#               'example': 842,
#               'pittsburgh': 843,
#               'se': 844,
#               'disable': 845,
#               'why': 846,
#               'lines': 847,
#               'sccm': 848,
#               'asheville': 849,
#               'hours': 850,
#               'mr': 851,
#               'nt': 852,
#               'centrify': 853,
#               'online': 854,
#               'unit': 855,
#               'fremont': 856,
#               'such': 857,
#               'modify': 858,
#               'signature': 859,
#               'cisco': 860,
#               'clean': 861,
#               'steven': 862,
#               'catalog': 863,
#               'fields': 864,
#               'labels': 865,
#               'lotus': 866,
#               'resource': 867,
#               'too': 868,
#               'division': 869,
#               'returned': 870,
#               'phones': 871,
#               'imaged': 872,
#               'jan': 873,
#               'jobs': 874,
#               'credit': 875,
#               'installing': 876,
#               'low': 877,
#               'life': 878,
#               'bit': 879,
#               'confirm': 880,
#               'weeks': 881,
#               'either': 882,
#               'adding': 883,
#               'spreadsheet': 884,
#               'started': 885,
#               'paul': 886,
#               'generate': 887,
#               'pending': 888,
#               'pricing': 889,
#               'pr': 890,
#               'sam': 891,
#               'approve': 892,
#               'germany': 893,
#               'session': 894,
#               'therefore': 895,
#               'programs': 896,
#               'export': 897,
#               'requirements': 898,
#               'van': 899,
#               'dl': 900,
#               'seems': 901,
#               'jde': 902,
#               'siebel': 903,
#               'transferred': 904,
#               'large': 905,
#               'reply': 906,
#               'url': 907,
#               'forms': 908,
#               'long': 909,
#               'purchasing': 910,
#               'tj': 911,
#               'mirror': 912,
#               'planning': 913,
#               'fixed': 914,
#               'jim': 915,
#               'coming': 916,
#               'nitro': 917,
#               'monthly': 918,
#               'acs': 919,
#               'ap': 920,
#               'facility': 921,
#               'mailto': 922,
#               'projects': 923,
#               'machines': 924,
#               'follows': 925,
#               'usb': 926,
#               'scheduled': 927,
#               'march': 928,
#               'fax': 929,
#               'high': 930,
#               'inc': 931,
#               'main': 932,
#               'onedrive': 933,
#               'roles': 934,
#               'manage': 935,
#               'vlan': 936,
#               'come': 937,
#               'pass': 938,
#               'tag': 939,
#               'creating': 940,
#               'erp': 941,
#               'search': 942,
#               'wrong': 943,
#               'click': 944,
#               'connecting': 945,
#               'versions': 946,
#               'even': 947,
#               'termination': 948,
#               'acrobat': 949,
#               'stage': 950,
#               'que': 951,
#               'refresh': 952,
#               'activated': 953,
#               'side': 954,
#               'stop': 955,
#               'u': 956,
#               'martin': 957,
#               'failed': 958,
#               'period': 959,
#               'tasks': 960,
#               'mentioned': 961,
#               'months': 962,
#               'ops': 963,
#               'processing': 964,
#               'virtual': 965,
#               'z': 966,
#               'pre': 967,
#               'raise': 968,
#               'specialist': 969,
#               'ago': 970,
#               'diego': 971,
#               'event': 972,
#               'west': 973,
#               'brian': 974,
#               'ordered': 975,
#               'thomas': 976,
#               'attach': 977,
#               'told': 978,
#               'acceso': 979,
#               'steve': 980,
#               'including': 981,
#               'objects': 982,
#               'staff': 983,
#               'pick': 984,
#               'tax': 985,
#               'three': 986,
#               'workspace': 987,
#               'anymore': 988,
#               'past': 989,
#               'recipient': 990,
#               'wms': 991,
#               'suite': 992,
#               'legacy': 993,
#               'bill': 994,
#               'lan': 995,
#               'logon': 996,
#               'worker': 997,
#               'believe': 998,
#               'clinical': 999,
#               ...}),
#  'vectors': None}

# %%
# cuda is not available on Mac
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# split the data into mini batches
BATCH_SIZE = 128
train_iterator, valid_iterator, test_iterator = BucketIterator.splits(
    (train_data, valid_data, test_data), 
    batch_size = BATCH_SIZE, 
    device = device)

# %%
# build the encoder that generates the context vector of the sentences
class Encoder(nn.Module):
    def __init__(self, input_dim, emb_dim, hid_dim, n_layers, dropout):
        super().__init__()
        
        self.input_dim = input_dim
        self.emb_dim = emb_dim
        self.hid_dim = hid_dim
        self.n_layers = n_layers
        self.dropout = dropout
        
        self.embedding = nn.Embedding(input_dim, emb_dim)
        
        self.rnn = nn.LSTM(emb_dim, hid_dim, n_layers, dropout = dropout)
        
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, src):
        
        #src = [src sent len, batch size]
        
        embedded = self.dropout(self.embedding(src))
        
        #embedded = [src sent len, batch size, emb dim]
        
        outputs, (hidden, cell) = self.rnn(embedded)
        
        #outputs = [src sent len, batch size, hid dim * n directions]
        #hidden = [n layers * n directions, batch size, hid dim]
        #cell = [n layers * n directions, batch size, hid dim]
        
        #outputs are always from the top hidden layer
        
        return hidden, cell

# %%
# buid the decoder that deciphers the context vectors to source sentences
class Decoder(nn.Module):
    def __init__(self, output_dim, emb_dim, hid_dim, n_layers, dropout):
        super().__init__()

        self.emb_dim = emb_dim
        self.hid_dim = hid_dim
        self.output_dim = output_dim
        self.n_layers = n_layers
        self.dropout = dropout
        
        self.embedding = nn.Embedding(output_dim, emb_dim)
        
        self.rnn = nn.LSTM(emb_dim, hid_dim, n_layers, dropout = dropout)
        
        self.out = nn.Linear(hid_dim, output_dim)
        
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, input, hidden, cell):
        
        #input = [batch size]
        #hidden = [n layers * n directions, batch size, hid dim]
        #cell = [n layers * n directions, batch size, hid dim]
        
        #n directions in the decoder will both always be 1, therefore:
        #hidden = [n layers, batch size, hid dim]
        #context = [n layers, batch size, hid dim]
        
        input = input.unsqueeze(0)
        
        #input = [1, batch size]
        
        embedded = self.dropout(self.embedding(input))
        
        #embedded = [1, batch size, emb dim]
                
        output, (hidden, cell) = self.rnn(embedded, (hidden, cell))
        
        #output = [sent len, batch size, hid dim * n directions]
        #hidden = [n layers * n directions, batch size, hid dim]
        #cell = [n layers * n directions, batch size, hid dim]
        
        #sent len and n directions will always be 1 in the decoder, therefore:
        #output = [1, batch size, hid dim]
        #hidden = [n layers, batch size, hid dim]
        #cell = [n layers, batch size, hid dim]
        
        prediction = self.out(output.squeeze(0))
        
        #prediction = [batch size, output dim]
        
        return prediction, hidden, cell

# %%
# build a sequence to sequence network that train the encoders to produce context vectors that represent the sentences well
class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder, device):
        super().__init__()
        
        self.encoder = encoder
        self.decoder = decoder
        self.device = device
        
        assert encoder.hid_dim == decoder.hid_dim, \
            "Hidden dimensions of encoder and decoder must be equal!"
        assert encoder.n_layers == decoder.n_layers, \
            "Encoder and decoder must have equal number of layers!"
        
    def forward(self, src, trg, teacher_forcing_ratio = 0.5):
        
        #src = [src sent len, batch size]
        #trg = [trg sent len, batch size]
        #teacher_forcing_ratio is probability to use teacher forcing
        #e.g. if teacher_forcing_ratio is 0.75 we use ground-truth inputs 75% of the time
        
        batch_size = trg.shape[1]
        max_len = trg.shape[0]
        trg_vocab_size = self.decoder.output_dim
        
        #tensor to store decoder outputs
        outputs = torch.zeros(max_len, batch_size, trg_vocab_size).to(self.device)
        
        #last hidden state of the encoder is used as the initial hidden state of the decoder
        hidden, cell = self.encoder(src)
        
        #first input to the decoder is the <sos> tokens
        input = trg[0,:]
        
        for t in range(1, max_len):
            
            output, hidden, cell = self.decoder(input, hidden, cell)
            outputs[t] = output
            teacher_force = random.random() < teacher_forcing_ratio
            top1 = output.max(1)[1]
            input = (trg[t] if teacher_force else top1)
        
        return outputs

# %%
# create a model
INPUT_DIM = len(SRC.vocab)
OUTPUT_DIM = len(TRG.vocab)
ENC_EMB_DIM = 256
DEC_EMB_DIM = 256
HID_DIM = 512
N_LAYERS = 2
ENC_DROPOUT = 0.5
DEC_DROPOUT = 0.5

enc = Encoder(INPUT_DIM, ENC_EMB_DIM, HID_DIM, N_LAYERS, ENC_DROPOUT)
dec = Decoder(OUTPUT_DIM, DEC_EMB_DIM, HID_DIM, N_LAYERS, DEC_DROPOUT)

model = Seq2Seq(enc, dec, device).to(device)

# initialize the weights with normal distribution
def init_weights(m):
    for name, param in m.named_parameters():
        nn.init.uniform_(param.data, -0.08, 0.08)
        
model.apply(init_weights)

# count the number of trainable parameters in the model
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(model):,} trainable parameters')

# define the optimizer as Adam
optimizer = optim.Adam(model.parameters())

# loss function
PAD_IDX = TRG.vocab.stoi['<pad>']
criterion = nn.CrossEntropyLoss(ignore_index = PAD_IDX)

# train
def train(model, iterator, optimizer, criterion, clip):
    
    model.train()
    
    epoch_loss = 0
    
    for i, batch in enumerate(iterator):
        
        src = batch.src
        trg = batch.trg
        
        optimizer.zero_grad()
        
        output = model(src, trg)
        
        #trg = [trg sent len, batch size]
        #output = [trg sent len, batch size, output dim]
        
        output = output[1:].view(-1, output.shape[-1])
        trg = trg[1:].view(-1)
        
        #trg = [(trg sent len - 1) * batch size]
        #output = [(trg sent len - 1) * batch size, output dim]
        
        loss = criterion(output, trg)
        
        loss.backward()
        
        torch.nn.utils.clip_grad_norm_(model.parameters(), clip)
        
        optimizer.step()
        
        epoch_loss += loss.item()
        
    return epoch_loss / len(iterator)

# evaluation
def evaluate(model, iterator, criterion):
    
    model.eval()
    
    epoch_loss = 0
    
    with torch.no_grad():
    
        for i, batch in enumerate(iterator):

            src = batch.src
            trg = batch.trg

            output = model(src, trg, 0) #turn off teacher forcing

            #trg = [trg sent len, batch size]
            #output = [trg sent len, batch size, output dim]

            output = output[1:].view(-1, output.shape[-1])
            trg = trg[1:].view(-1)

            #trg = [(trg sent len - 1) * batch size]
            #output = [(trg sent len - 1) * batch size, output dim]

            loss = criterion(output, trg)
            
            epoch_loss += loss.item()
        
    return epoch_loss / len(iterator)

# epoch timing
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs
# Out:
# The model has 42,495,466 trainable parameters

# %%
# train
N_EPOCHS = 10
CLIP = 1

best_valid_loss = float('inf')

for epoch in range(N_EPOCHS):
    
    start_time = time.time()
    
    train_loss = train(model, train_iterator, optimizer, criterion, CLIP)
    valid_loss = evaluate(model, valid_iterator, criterion)
    
    end_time = time.time()
    
    epoch_mins, epoch_secs = epoch_time(start_time, end_time)
    
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save (model.state_dict(), 'tut1-model.pt')
    
    print(f'Epoch: {epoch+1:02} | Time: {epoch_mins}m {epoch_secs}s')
    print(f'\tTrain Loss: {train_loss:.3f} | Train PPL: {math.exp(train_loss):7.3f}')
    print(f'\t Val. Loss: {valid_loss:.3f} |  Val. PPL: {math.exp(valid_loss):7.3f}')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-138-71cfa6b88149> in <module>
#       9     start_time = time.time()
#      10
# ---> 11     train_loss = train(model, train_iterator, optimizer, criterion, CLIP)
#      12     valid_loss = evaluate(model, valid_iterator, criterion)
#      13
#
# <ipython-input-137-a5a23131a0b0> in train(model, iterator, optimizer, criterion, clip)
#      61         loss = criterion(output, trg)
#      62
# ---> 63         loss.backward()
#      64
#      65         torch.nn.utils.clip_grad_norm_(model.parameters(), clip)
#
# ~/anaconda3/envs/pytorchPractice/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     116                 products. Defaults to ``False``.
#     117         """
# --> 118         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     119
#     120     def register_hook(self, hook):
#
# ~/anaconda3/envs/pytorchPractice/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      91     Variable._execution_engine.run_backward(
#      92         tensors, grad_tensors, retain_graph, create_graph,
# ---> 93         allow_unreachable=True)  # allow_unreachable flag
#      94
#      95
#
# KeyboardInterrupt:

# %%
model.load_state_dict(torch.load('tut1-model.pt'))

test_loss = evaluate(model, test_iterator, criterion)

print(f'| Test Loss: {test_loss:.3f} | Test PPL: {math.exp(test_loss):7.3f} |')
